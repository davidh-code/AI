# %% [markdown]
# # Unit 3 Final Project
#
# Before you get started on your project, take a moment to review how you can make requests from the following APIs:
# - **ESPN**
# - **TikTok**
# - **X**
# - **Spotify**
#
# First, you will need to set up your API credentials:
#    - **Spotify**: `SPOTIFY_CLIENT_ID` and `SPOTIFY_CLIENT_SECRET` from https://developer.spotify.com/dashboard
#    - **X (Twitter)**: `X_BEARER_TOKEN` from https://developer.twitter.com/en/portal/dashboard
#    - **TikTok**: No authentication required!
#    - **ESPN**: No authentication required!

# %%
# Import required libraries
import requests
import json
import random
import asyncio
import os

# %% [markdown]
# ## 1. Spotify API - Random Song

# %%
# Setup API authorization before making request
SPOTIFY_CLIENT_ID = "ADD YOUR ID HERE"
SPOTIFY_CLIENT_SECRET = "ADD YOUR SECRET HERE"

# Get access token
auth_response = requests.post('https://accounts.spotify.com/api/token', {
    'grant_type': 'client_credentials',
    'client_id': SPOTIFY_CLIENT_ID,
    'client_secret': SPOTIFY_CLIENT_SECRET,
})

auth_data = auth_response.json()
access_token = auth_data['access_token']

headers = {
    'Authorization': f'Bearer {access_token}'
}

# %%
# Search for a random popular track
search_query = random.choice(['pop', 'rock', 'hip hop', 'jazz', 'electronic'])
spotify_response = requests.get(
    'https://api.spotify.com/v1/search',
    headers=headers,
    params={'q': search_query, 'type': 'track', 'limit': 50}
)

print(spotify_response)
spotify_data = spotify_response.json()
print(spotify_data['tracks']['items'][0]['artists'][0]['name'])
print(spotify_data['tracks']['items'][0]['name'])
# Out:
# <Response [200]>
# Brenda Lee
# Rockin' Around The Christmas Tree

# %% [markdown]
# ## 2. X (Twitter) API - Random Recent Post

# %%
# Setup API authorization before making request

X_BEARER_TOKEN = "ADD YOUR BEARER TOKEN HERE"

headers = {
    'Authorization': f'Bearer {X_BEARER_TOKEN}'
}

# %%
# Search for recent tweets about a random topic
search_topic = random.choice(['sports', 'technology', 'music', 'news', 'science'])
x_response = requests.get(
    'https://api.twitter.com/2/tweets/search/recent',
    headers=headers,
    params={
        'query': f'{search_topic} -is:retweet lang:en',
        'max_results': 10,
        'tweet.fields': 'created_at,public_metrics,author_id'
    }
)

x_data = x_response.json()
if 'data' in x_data and x_data['data']:
    random_tweet = random.choice(x_data['data'])
    print(f"\nRandom Tweet Found (Topic: {search_topic}):")
    print(f"  Text: {random_tweet['text'][:200]}...")
    if 'public_metrics' in random_tweet:
        print(f"  Likes: {random_tweet['public_metrics'].get('like_count', 0)}")
        print(f"  Retweets: {random_tweet['public_metrics'].get('retweet_count', 0)}")
# Out:
# Random Tweet Found (Topic: sports):
#   Text: After dropping to No. 7 in the latest CFP rankings, Texas A&amp;M HC Mike Elko is asking for more clarity regarding the Aggies' surprising drop. https://t.co/o3GVk8ljpQ...
#   Likes: 0
#   Retweets: 0

# %% [markdown]
# ## 3. TikTok API - Random Trending Video
#
# *Note, this API will most likely only work when using a local version of Jupyter Notebooks because access to a browser like chromium.*

# %%
# !pip install TikTokApi
# !playwright install
# Out:
# Collecting TikTokApi
#   Downloading tiktokapi-7.2.1-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0,>=2.31.0 in /opt/anaconda3/lib/python3.13/site-packages (from TikTokApi) (2.32.3)
# Collecting playwright<2.0,>=1.36.0 (from TikTokApi)
#   Downloading playwright-1.56.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1.0,>=0.27.0 in /opt/anaconda3/lib/python3.13/site-packages (from TikTokApi) (0.28.1)
# Collecting proxyproviders<0.3.0,>=0.2.1 (from TikTokApi)
#   Downloading proxyproviders-0.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.27.0->TikTokApi) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.27.0->TikTokApi) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.27.0->TikTokApi) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.27.0->TikTokApi) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0,>=0.27.0->TikTokApi) (0.16.0)
# Collecting pyee<14,>=13 (from playwright<2.0,>=1.36.0->TikTokApi)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from playwright<2.0,>=1.36.0->TikTokApi) (3.1.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.13/site-packages (from pyee<14,>=13->playwright<2.0,>=1.36.0->TikTokApi) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.31.0->TikTokApi) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.31.0->TikTokApi) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1.0,>=0.27.0->TikTokApi) (1.3.0)
# Downloading tiktokapi-7.2.1-py3-none-any.whl (65 kB)
# Downloading playwright-1.56.0-py3-none-macosx_11_0_arm64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 57.3 MB/s eta 0:00:00a 0:00:01
# Downloading proxyproviders-0.2.1-py3-none-any.whl (16 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, proxyproviders, playwright, TikTokApi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [TikTokApi]/4 [TikTokApi]]
# Successfully installed TikTokApi-7.2.1 playwright-1.56.0 proxyproviders-0.2.1 pyee-13.0.0
# Removing unused browser at /Users/soniaspindt/Library/Caches/ms-playwright/chromium-1140
# Removing unused browser at /Users/soniaspindt/Library/Caches/ms-playwright/ffmpeg-1010
# Removing unused browser at /Users/soniaspindt/Library/Caches/ms-playwright/firefox-1465
# Removing unused browser at /Users/soniaspindt/Library/Caches/ms-playwright/webkit-2083
# Downloading Chromium 141.0.7390.37 (playwright build v1194) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1194/chromium-mac-arm64.zip
# 129.7 MiB [                    ] 0% 0.0s129.7 MiB [                    ] 0% 57.7s129.7 MiB [                    ] 0% 39.7s129.7 MiB [                    ] 0% 39.2s129.7 MiB [                    ] 0% 34.4s129.7 MiB [                    ] 0% 28.1s129.7 MiB [                    ] 0% 24.0s129.7 MiB [                    ] 0% 20.0s129.7 MiB [                    ] 0% 15.4s129.7 MiB [                    ] 1% 12.3s129.7 MiB [                    ] 1% 10.4s129.7 MiB [                    ] 2% 8.2s129.7 MiB [=                   ] 3% 6.3s129.7 MiB [=                   ] 4% 5.0s129.7 MiB [=                   ] 4% 5.1s129.7 MiB [=                   ] 5% 4.7s129.7 MiB [=                   ] 5% 5.2s129.7 MiB [=                   ] 6% 4.9s129.7 MiB [=                   ] 7% 4.5s129.7 MiB [==                  ] 8% 4.2s129.7 MiB [==                  ] 9% 3.9s129.7 MiB [==                  ] 10% 3.6s129.7 MiB [==                  ] 11% 3.4s129.7 MiB [==                  ] 12% 3.2s129.7 MiB [===                 ] 13% 3.0s129.7 MiB [===                 ] 14% 3.0s129.7 MiB [===                 ] 15% 2.8s129.7 MiB [===                 ] 16% 2.8s129.7 MiB [===                 ] 17% 2.8s129.7 MiB [====                ] 18% 2.7s129.7 MiB [====                ] 19% 2.6s129.7 MiB [====                ] 19% 2.5s129.7 MiB [====                ] 20% 2.5s129.7 MiB [====                ] 21% 2.4s129.7 MiB [=====               ] 22% 2.3s129.7 MiB [=====               ] 23% 2.3s129.7 MiB [=====               ] 24% 2.2s129.7 MiB [=====               ] 25% 2.1s129.7 MiB [=====               ] 26% 2.1s129.7 MiB [======              ] 27% 2.0s129.7 MiB [======              ] 28% 2.0s129.7 MiB [======              ] 29% 1.9s129.7 MiB [======              ] 30% 1.9s129.7 MiB [======              ] 31% 1.8s129.7 MiB [======              ] 32% 1.8s129.7 MiB [=======             ] 33% 1.8s129.7 MiB [=======             ] 34% 1.7s129.7 MiB [=======             ] 35% 1.7s129.7 MiB [=======             ] 37% 1.6s129.7 MiB [========            ] 38% 1.6s129.7 MiB [========            ] 39% 1.6s129.7 MiB [========            ] 40% 1.5s129.7 MiB [========            ] 41% 1.5s129.7 MiB [========            ] 42% 1.5s129.7 MiB [=========           ] 43% 1.4s129.7 MiB [=========           ] 44% 1.4s129.7 MiB [=========           ] 45% 1.4s129.7 MiB [=========           ] 46% 1.3s129.7 MiB [=========           ] 47% 1.3s129.7 MiB [==========          ] 48% 1.3s129.7 MiB [==========          ] 49% 1.3s129.7 MiB [==========          ] 49% 1.2s129.7 MiB [==========          ] 51% 1.2s129.7 MiB [===========         ] 52% 1.1s129.7 MiB [===========         ] 53% 1.1s129.7 MiB [===========         ] 54% 1.1s129.7 MiB [===========         ] 55% 1.1s129.7 MiB [===========         ] 56% 1.0s129.7 MiB [============        ] 57% 1.0s129.7 MiB [============        ] 58% 1.0s129.7 MiB [============        ] 59% 0.9s129.7 MiB [============        ] 61% 0.9s129.7 MiB [=============       ] 62% 0.9s129.7 MiB [=============       ] 63% 0.8s129.7 MiB [=============       ] 64% 0.8s129.7 MiB [=============       ] 65% 0.8s129.7 MiB [=============       ] 66% 0.8s129.7 MiB [==============      ] 67% 0.8s129.7 MiB [==============      ] 69% 0.7s129.7 MiB [==============      ] 70% 0.7s129.7 MiB [==============      ] 71% 0.7s129.7 MiB [==============      ] 72% 0.7s129.7 MiB [===============     ] 73% 0.6s129.7 MiB [===============     ] 74% 0.6s129.7 MiB [===============     ] 75% 0.6s129.7 MiB [===============     ] 76% 0.5s129.7 MiB [================    ] 77% 0.5s129.7 MiB [================    ] 78% 0.5s129.7 MiB [================    ] 79% 0.5s129.7 MiB [================    ] 80% 0.5s129.7 MiB [================    ] 81% 0.4s129.7 MiB [=================   ] 82% 0.4s129.7 MiB [=================   ] 83% 0.4s129.7 MiB [=================   ] 84% 0.3s129.7 MiB [=================   ] 85% 0.3s129.7 MiB [=================   ] 86% 0.3s129.7 MiB [==================  ] 87% 0.3s129.7 MiB [==================  ] 8 ...
# Chromium 141.0.7390.37 (playwright build v1194) downloaded to /Users/soniaspindt/Library/Caches/ms-playwright/chromium-1194
# Downloading Chromium Headless Shell 141.0.7390.37 (playwright build v1194) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1194/chromium-headless-shell-mac-arm64.zip
# 81.7 MiB [                    ] 0% 0.0s81.7 MiB [                    ] 0% 31.3s81.7 MiB [                    ] 0% 26.3s81.7 MiB [                    ] 0% 23.5s81.7 MiB [                    ] 0% 20.8s81.7 MiB [                    ] 0% 17.3s81.7 MiB [                    ] 0% 13.9s81.7 MiB [                    ] 1% 11.3s81.7 MiB [                    ] 1% 8.8s81.7 MiB [                    ] 2% 7.0s81.7 MiB [=                   ] 3% 5.7s81.7 MiB [=                   ] 4% 4.4s81.7 MiB [=                   ] 5% 3.4s81.7 MiB [=                   ] 7% 2.8s81.7 MiB [==                  ] 8% 2.6s81.7 MiB [==                  ] 9% 2.5s81.7 MiB [==                  ] 10% 2.3s81.7 MiB [==                  ] 12% 2.1s81.7 MiB [===                 ] 14% 1.9s81.7 MiB [===                 ] 16% 1.8s81.7 MiB [===                 ] 17% 1.7s81.7 MiB [====                ] 18% 1.6s81.7 MiB [====                ] 20% 1.5s81.7 MiB [====                ] 21% 1.5s81.7 MiB [=====               ] 22% 1.5s81.7 MiB [=====               ] 24% 1.4s81.7 MiB [=====               ] 25% 1.3s81.7 MiB [=====               ] 27% 1.3s81.7 MiB [======              ] 28% 1.2s81.7 MiB [======              ] 29% 1.2s81.7 MiB [======              ] 31% 1.2s81.7 MiB [======              ] 32% 1.2s81.7 MiB [=======             ] 33% 1.2s81.7 MiB [=======             ] 34% 1.1s81.7 MiB [=======             ] 36% 1.1s81.7 MiB [=======             ] 36% 1.2s81.7 MiB [=======             ] 37% 1.2s81.7 MiB [========            ] 39% 1.1s81.7 MiB [========            ] 40% 1.1s81.7 MiB [========            ] 41% 1.1s81.7 MiB [=========           ] 42% 1.0s81.7 MiB [=========           ] 44% 1.0s81.7 MiB [=========           ] 45% 1.0s81.7 MiB [=========           ] 47% 0.9s81.7 MiB [==========          ] 48% 0.9s81.7 MiB [==========          ] 49% 0.9s81.7 MiB [==========          ] 51% 0.8s81.7 MiB [==========          ] 52% 0.8s81.7 MiB [===========         ] 53% 0.8s81.7 MiB [===========         ] 54% 0.8s81.7 MiB [===========         ] 56% 0.7s81.7 MiB [===========         ] 57% 0.7s81.7 MiB [============        ] 59% 0.7s81.7 MiB [============        ] 61% 0.6s81.7 MiB [=============       ] 63% 0.6s81.7 MiB [=============       ] 64% 0.6s81.7 MiB [=============       ] 65% 0.6s81.7 MiB [=============       ] 66% 0.5s81.7 MiB [==============      ] 68% 0.5s81.7 MiB [==============      ] 69% 0.5s81.7 MiB [==============      ] 71% 0.5s81.7 MiB [===============     ] 72% 0.4s81.7 MiB [===============     ] 73% 0.4s81.7 MiB [===============     ] 75% 0.4s81.7 MiB [===============     ] 76% 0.4s81.7 MiB [================    ] 78% 0.3s81.7 MiB [================    ] 79% 0.3s81.7 MiB [================    ] 80% 0.3s81.7 MiB [=================   ] 82% 0.3s81.7 MiB [=================   ] 83% 0.3s81.7 MiB [=================   ] 85% 0.2s81.7 MiB [=================   ] 87% 0.2s81.7 MiB [==================  ] 88% 0.2s81.7 MiB [==================  ] 90% 0.2s81.7 MiB [==================  ] 92% 0.1s81.7 MiB [=================== ] 93% 0.1s81.7 MiB [=================== ] 94% 0.1s81.7 MiB [=================== ] 96% 0.1s81.7 MiB [====================] 97% 0.0s81.7 MiB [====================] 98% 0.0s81.7 MiB [====================] 100% 0.0s
# Chromium Headless Shell 141.0.7390.37 (playwright build v1194) downloaded to /Users/soniaspindt/Library/Caches/ms-playwright/chromium_headless_shell-1194
# Downloading Firefox 142.0.1 (playwright build v1495) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1495/firefox-mac-arm64.zip
# 89.9 MiB [                    ] 0% 0.0s89.9 MiB [                    ] 0% 38.6s89.9 MiB [                    ] 0% 28.7s89.9 MiB [                    ] 0% 26.4s89.9 MiB [                    ] 0% 22.4s89.9 MiB [                    ] 0% 20.6s89.9 MiB [                    ] 0% 17.7s89.9 MiB [                    ] 0% 13.8s89.9 MiB [                    ] 1% 11.0s89.9 MiB [                    ] 1% 9.4s89.9 MiB [                    ] 2% 7.3s89.9 MiB [=                   ] 3% 5.7s89.9 MiB [=                   ] 4% 4.5s89.9 MiB [=                   ] 5% 4.2s89.9 MiB [=                   ] 6% 3.6s89.9 MiB [==                  ] 7% 3.1s89.9 MiB [==                  ] 9% 2.9s89.9 MiB [==                  ] 10% 2.6s89.9 MiB [==                  ] 10% 2.7s89.9 MiB [==                  ] 12% 2.5s89.9 MiB [===                 ] 13% 2.3s89.9 MiB [===                 ] 15% 2.1s89.9 MiB [===                 ] 17% 2.0s89.9 MiB [====                ] 18% 1.9s89.9 MiB [====                ] 19% 1.9s89.9 MiB [====                ] 20% 1.9s89.9 MiB [====                ] 22% 1.7s89.9 MiB [=====               ] 23% 1.6s89.9 MiB [=====               ] 24% 1.6s89.9 MiB [=====               ] 26% 1.5s89.9 MiB [=====               ] 27% 1.5s89.9 MiB [======              ] 28% 1.4s89.9 MiB [======              ] 30% 1.4s89.9 MiB [======              ] 31% 1.3s89.9 MiB [=======             ] 32% 1.3s89.9 MiB [=======             ] 33% 1.3s89.9 MiB [=======             ] 34% 1.2s89.9 MiB [=======             ] 35% 1.2s89.9 MiB [=======             ] 37% 1.2s89.9 MiB [========            ] 38% 1.1s89.9 MiB [========            ] 39% 1.1s89.9 MiB [========            ] 40% 1.1s89.9 MiB [=========           ] 42% 1.0s89.9 MiB [=========           ] 44% 1.0s89.9 MiB [=========           ] 45% 1.0s89.9 MiB [=========           ] 47% 0.9s89.9 MiB [==========          ] 48% 0.9s89.9 MiB [==========          ] 50% 0.9s89.9 MiB [==========          ] 51% 0.8s89.9 MiB [===========         ] 52% 0.8s89.9 MiB [===========         ] 53% 0.8s89.9 MiB [===========         ] 55% 0.7s89.9 MiB [===========         ] 56% 0.7s89.9 MiB [============        ] 58% 0.7s89.9 MiB [============        ] 59% 0.7s89.9 MiB [============        ] 61% 0.6s89.9 MiB [=============       ] 62% 0.6s89.9 MiB [=============       ] 64% 0.6s89.9 MiB [=============       ] 65% 0.6s89.9 MiB [=============       ] 67% 0.5s89.9 MiB [==============      ] 68% 0.5s89.9 MiB [==============      ] 69% 0.5s89.9 MiB [==============      ] 70% 0.5s89.9 MiB [==============      ] 72% 0.4s89.9 MiB [===============     ] 72% 0.4s89.9 MiB [===============     ] 74% 0.4s89.9 MiB [===============     ] 76% 0.4s89.9 MiB [================    ] 77% 0.3s89.9 MiB [================    ] 78% 0.3s89.9 MiB [================    ] 80% 0.3s89.9 MiB [================    ] 81% 0.3s89.9 MiB [=================   ] 82% 0.3s89.9 MiB [=================   ] 84% 0.2s89.9 MiB [=================   ] 85% 0.2s89.9 MiB [=================   ] 87% 0.2s89.9 MiB [==================  ] 88% 0.2s89.9 MiB [==================  ] 90% 0.1s89.9 MiB [==================  ] 91% 0.1s89.9 MiB [=================== ] 94% 0.1s89.9 MiB [=================== ] 95% 0.1s89.9 MiB [=================== ] 96% 0.0s89.9 MiB [====================] 98% 0.0s89.9 MiB [====================] 99% 0.0s89.9 MiB [====================] 100% 0.0s
# Firefox 142.0.1 (playwright build v1495) downloaded to /Users/soniaspindt/Library/Caches/ms-playwright/firefox-1495
# You are using a frozen webkit browser which does not receive updates anymore on mac13-arm64. Please update to the latest version of your operating system to test up-to-date browsers.
# Downloading Webkit playwright build v2140 from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2140/webkit-mac-13-arm64.zip
# 73.1 MiB [                    ] 0% 0.0s73.1 MiB [                    ] 0% 27.6s73.1 MiB [                    ] 0% 22.3s73.1 MiB [                    ] 0% 20.3s73.1 MiB [                    ] 0% 19.1s73.1 MiB [                    ] 0% 16.5s73.1 MiB [                    ] 0% 12.4s73.1 MiB [                    ] 1% 10.1s73.1 MiB [                    ] 1% 7.8s73.1 MiB [                    ] 2% 6.3s73.1 MiB [=                   ] 3% 4.9s73.1 MiB [=                   ] 4% 4.1s73.1 MiB [=                   ] 6% 3.1s73.1 MiB [=                   ] 6% 3.0s73.1 MiB [==                  ] 8% 2.7s73.1 MiB [==                  ] 9% 2.3s73.1 MiB [==                  ] 11% 2.1s73.1 MiB [==                  ] 12% 2.2s73.1 MiB [===                 ] 13% 2.0s73.1 MiB [===                 ] 16% 1.7s73.1 MiB [====                ] 17% 1.8s73.1 MiB [====                ] 18% 1.7s73.1 MiB [====                ] 19% 1.7s73.1 MiB [=====               ] 23% 1.5s73.1 MiB [=====               ] 24% 1.4s73.1 MiB [=====               ] 27% 1.3s73.1 MiB [======              ] 28% 1.3s73.1 MiB [======              ] 30% 1.2s73.1 MiB [======              ] 32% 1.1s73.1 MiB [=======             ] 33% 1.1s73.1 MiB [=======             ] 35% 1.0s73.1 MiB [=======             ] 37% 1.0s73.1 MiB [========            ] 39% 0.9s73.1 MiB [========            ] 40% 0.9s73.1 MiB [========            ] 42% 0.9s73.1 MiB [=========           ] 44% 0.8s73.1 MiB [=========           ] 46% 0.8s73.1 MiB [==========          ] 48% 0.8s73.1 MiB [==========          ] 49% 0.7s73.1 MiB [==========          ] 51% 0.7s73.1 MiB [===========         ] 53% 0.7s73.1 MiB [===========         ] 55% 0.6s73.1 MiB [===========         ] 57% 0.6s73.1 MiB [============        ] 58% 0.6s73.1 MiB [============        ] 60% 0.5s73.1 MiB [=============       ] 62% 0.5s73.1 MiB [=============       ] 63% 0.5s73.1 MiB [=============       ] 65% 0.5s73.1 MiB [==============      ] 67% 0.4s73.1 MiB [==============      ] 68% 0.4s73.1 MiB [==============      ] 69% 0.4s73.1 MiB [==============      ] 71% 0.4s73.1 MiB [===============     ] 73% 0.4s73.1 MiB [===============     ] 75% 0.3s73.1 MiB [===============     ] 77% 0.3s73.1 MiB [================    ] 78% 0.3s73.1 MiB [================    ] 80% 0.3s73.1 MiB [================    ] 82% 0.2s73.1 MiB [=================   ] 84% 0.2s73.1 MiB [=================   ] 85% 0.2s73.1 MiB [==================  ] 88% 0.2s73.1 MiB [==================  ] 89% 0.1s73.1 MiB [==================  ] 91% 0.1s73.1 MiB [=================== ] 93% 0.1s73.1 MiB [=================== ] 94% 0.1s73.1 MiB [=================== ] 96% 0.0s73.1 MiB [====================] 98% 0.0s73.1 MiB [====================] 99% 0.0s73.1 MiB [====================] 100% 0.0s
# Webkit playwright build v2140 downloaded to /Users/soniaspindt/Library/Caches/ms-playwright/webkit_mac13_arm64_special-2140
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-mac-arm64.zip
# 1 MiB [                    ] 1% 0.0s1 MiB [=                   ] 6% 0.4s1 MiB [==                  ] 12% 0.3s1 MiB [====                ] 19% 0.3s1 MiB [======              ] 29% 0.2s1 MiB [========            ] 42% 0.1s1 MiB [============        ] 60% 0.1s1 MiB [==================  ] 89% 0.0s1 MiB [====================] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /Users/soniaspindt/Library/Caches/ms-playwright/ffmpeg-1011

# %%
from TikTokApi import TikTokApi

async def get_tiktok_video():
    async with TikTokApi() as api:
        await api.create_sessions(
            ms_tokens=[os.environ.get("ms_token")],
            num_sessions=1,
            sleep_after=3,
            headless=False  # ← Makes browser visible!
        )
        
        videos = []
        async for video in api.trending.videos(count=10):
            videos.append(video)
        
        if videos:
            video = random.choice(videos)
            print(f"Found video by @{video.author.username}")
            print(f"URL: https://www.tiktok.com/@{video.author.username}/video/{video.id}")

await get_tiktok_video()
# Out:
# Found video by @nne_hub
# URL: https://www.tiktok.com/@nne_hub/video/7546892254019964215

# %% [markdown]
# ## 4. ESPN API (Hidden) - Random Basketball Game
#
# *Note, this API will most likely only work when using a local version of Jupyter Notebooks because the cloud permission settings appear to block ESPN.*

# %%
espn_response = requests.get(
    'http://site.api.espn.com/apis/site/v2/sports/basketball/nba/scoreboard'
)

espn_data = espn_response.json()
espn_data
# Out:
# {'leagues': [{'id': '46',
#    'uid': 's:40~l:46',
#    'name': 'National Basketball Association',
#    'abbreviation': 'NBA',
#    'slug': 'nba',
#    'season': {'year': 2026,
#     'startDate': '2025-10-01T07:00Z',
#     'endDate': '2026-06-27T06:59Z',
#     'displayName': '2025-26',
#     'type': {'id': '2',
#      'type': 2,
#      'name': 'Regular Season',
#      'abbreviation': 'reg'}},
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nba.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2018-06-05T12:07Z'},
#     {'href': 'https://a.espncdn.com/combiner/i?img=/i/teamlogos/leagues/500-dark/nba.png&w=500&h=500&transparent=true',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'dark'],
#      'lastUpdated': '2025-12-02T23:30Z'}],
#    'calendarType': 'day',
#    'calendarIsWhitelist': True,
#    'calendarStartDate': '2025-10-01T07:00Z',
#    'calendarEndDate': '2026-06-27T06:59Z',
#    'calendar': ['2025-10-02T07:00Z',
#     '2025-10-03T07:00Z',
#     '2025-10-04T07:00Z',
#     '2025-10-05T07:00Z',
#     '2025-10-06T07:00Z',
#     '2025-10-07T07:00Z',
#     '2025-10-08T07:00Z',
#     '2025-10-09T07:00Z',
#     '2025-10-10T07:00Z',
#     '2025-10-11T07:00Z',
#     '2025-10-12T07:00Z',
#     '2025-10-13T07:00Z',
#     '2025-10-14T07:00Z',
#     '2025-10-15T07:00Z',
#     '2025-10-16T07:00Z',
#     '2025-10-17T07:00Z',
#     '2025-10-21T07:00Z',
#     '2025-10-22T07:00Z',
#     '2025-10-23T07:00Z',
#     '2025-10-24T07:00Z',
#     '2025-10-25T07:00Z',
#     '2025-10-26T07:00Z',
#     '2025-10-27T07:00Z',
#     '2025-10-28T07:00Z',
#     '2025-10-29T07:00Z',
#     '2025-10-30T07:00Z',
#     '2025-10-31T07:00Z',
#     '2025-11-01T07:00Z',
#     '2025-11-02T07:00Z',
#     '2025-11-03T08:00Z',
#     '2025-11-04T08:00Z',
#     '2025-11-05T08:00Z',
#     '2025-11-06T08:00Z',
#     '2025-11-07T08:00Z',
#     '2025-11-08T08:00Z',
#     '2025-11-09T08:00Z',
#     '2025-11-10T08:00Z',
#     '2025-11-11T08:00Z',
#     '2025-11-12T08:00Z',
#     '2025-11-13T08:00Z',
#     '2025-11-14T08:00Z',
#     '2025-11-15T08:00Z',
#     '2025-11-16T08:00Z',
#     '2025-11-17T08:00Z',
#     '2025-11-18T08:00Z',
#     '2025-11-19T08:00Z',
#     '2025-11-20T08:00Z',
#     '2025-11-21T08:00Z',
#     '2025-11-22T08:00Z',
#     '2025-11-23T08:00Z',
#     '2025-11-24T08:00Z',
#     '2025-11-25T08:00Z',
#     '2025-11-26T08:00Z',
#     '2025-11-28T08:00Z',
#     '2025-11-29T08:00Z',
#     '2025-11-30T08:00Z',
#     '2025-12-01T08:00Z',
#     '2025-12-02T08:00Z',
#     '2025-12-03T08:00Z',
#     '2025-12-04T08:00Z',
#     '2025-12-05T08:00Z',
#     '2025-12-06T08:00Z',
#     '2025-12-07T08:00Z',
#     '2025-12-08T08:00Z',
#     '2025-12-09T08:00Z',
#     '2025-12-10T08:00Z',
#     '2025-12-11T08:00Z',
#     '2025-12-12T08:00Z',
#     '2025-12-13T08:00Z',
#     '2025-12-14T08:00Z',
#     '2025-12-15T08:00Z',
#     '2025-12-16T08:00Z',
#     '2025-12-17T08:00Z',
#     '2025-12-18T08:00Z',
#     '2025-12-19T08:00Z',
#     '2025-12-20T08:00Z',
#     '2025-12-21T08:00Z',
#     '2025-12-22T08:00Z',
#     '2025-12-23T08:00Z',
#     '2025-12-25T08:00Z',
#     '2025-12-26T08:00Z',
#     '2025-12-27T08:00Z',
#     '2025-12-28T08:00Z',
#     '2025-12-29T08:00Z',
#     '2025-12-30T08:00Z',
#     '2025-12-31T08:00Z',
#     '2026-01-01T08:00Z',
#     '2026-01-02T08:00Z',
#     '2026-01-03T08:00Z',
#     '2026-01-04T08:00Z',
#     '2026-01-05T08:00Z',
#     '2026-01-06T08:00Z',
#     '2026-01-07T08:00Z',
#     '2026-01-08T08:00Z',
#     '2026-01-09T08:00Z',
#     '2026-01-10T08:00Z',
#     '2026-01-11T08:00Z',
#     '2026-01-12T08:00Z',
#     '2026-01-13T08:00Z',
#     '2026-01-14T08:00Z',
#     '2026-01-15T08:00Z',
#     '2026-01-16T08:00Z',
#     '2026-01-17T08:00Z',
#     '2026-01-18T08:00Z',
#     '2026-01-19T08:00Z',
#     '2026-01-20T08:00Z',
#     '2026-01-21T08:00Z',
#     '2026-01-22T08:00Z',
#     '2026-01-23T08:00Z',
#     '2026-01-24T08:00Z',
#     '2026-01-25T08:00Z',
#     '2026-01-26T08:00Z',
#     '2026-01-27T08:00Z',
#     '2026-01-28T08:00Z',
#     '2026-01-29T08:00Z',
#     '2026-01-30T08:00Z',
#     '2026-01-31T08:00Z',
#     '2026-02-01T08:00Z',
#     '2026-02-02T08:00Z',
#     '2026-02-03T08:00Z',
#     '2026-02-04T08:00Z',
#     '2026-02-05T08:00Z',
#     '2026-02-06T08:00Z',
#     '2026-02-07T08:00Z',
#     '2026-02-08T08:00Z',
#     '2026-02-09T08:00Z',
#     '2026-02-10T08:00Z',
#     '2026-02-11T08:00Z',
#     '2026-02-12T08:00Z',
#     '2026-02-19T08:00Z',
#     '2026-02-20T08:00Z',
#     '2026-02-21T08:00Z',
#     '2026-02-22T08:00Z',
#     '2026-02-23T08:00Z',
#     '2026-02-24T08:00Z',
#     '2026-02-25T08:00Z',
#     '2026-02-26T08:00Z',
#     '2026-02-27T08:00Z',
#     '2026-02-28T08:00Z',
#     '2026-03-01T08:00Z',
#     '2026-03-02T08:00Z',
#     '2026-03-03T08:00Z',
#     '2026-03-04T08:00Z',
#     '2026-03-05T08:00Z',
#     '2026-03-06T08:00Z',
#     '2026-03-07T08:00Z',
#     '2026-03-08T08:00Z',
#     '2026-03-09T07:00Z',
#     '2026-03-10T07:00Z',
#     '2026-03-11T07:00Z',
#     '2026-03-12T07:00Z',
#     '2026-03-13T07:00Z',
#     '2026-03-14T07:00Z',
#     '2026-03-15T07:00Z',
#     '2026-03-16T07:00Z',
#     '2026-03-17T07:00Z',
#     '2026-03-18T07:00Z',
#     '2026-03-19T07:00Z',
#     '2026-03-20T07:00Z',
#     '2026-03-21T07:00Z',
#     '2026-03-22T07:00Z',
#     '2026-03-23T07:00Z',
#     '2026-03-24T07:00Z',
#     '2026-03-25T07:00Z',
#     '2026-03-26T07:00Z',
#     '2026-03-27T07:00Z',
#     '2026-03-28T07:00Z',
#     '2026-03-29T07:00Z',
#     '2026-03-30T07:00Z',
#     '2026-03-31T07:00Z',
#     '2026-04-01T07:00Z',
#     '2026-04-02T07:00Z',
#     '2026-04-03T07:00Z',
#     '2026-04-04T07:00Z',
#     '2026-04-05T07:00Z',
#     '2026-04-06T07:00Z',
#     '2026-04-07T07:00Z',
#     '2026-04-08T07:00Z',
#     '2026-04-09T07:00Z',
#     '2026-04-10T07:00Z',
#     '2026-04-12T07:00Z']}],
#  'season': {'type': 2, 'year': 2026},
#  'day': {'date': '2025-12-03'},
#  'events': [{'id': '401810179',
#    'uid': 's:40~l:46~e:401810179',
#    'date': '2025-12-04T00:00Z',
#    'name': 'Portland Trail Blazers at Cleveland Cavaliers',
#    'shortName': 'POR @ CLE',
#    'season': {'year': 2026, 'type': 2, 'slug': 'regular-season'},
#    'competitions': [{'id': '401810179',
#      'uid': 's:40~l:46~e:401810179~c:401810179',
#      'date': '2025-12-04T00:00Z',
#      'attendance': 19432,
#      'type': {'id': '1', 'abbreviation': 'STD'},
#      'timeValid': True,
#      'neutralSite': False,
#      'conferenceCompetition': False,
#      'playByPlayAvailable': True,
#      'recent': True,
#      'venue': {'id': '3417',
#       'fullName': 'Rocket Arena',
#       'address': {'city': 'Cleveland', 'state': 'OH'},
#       'indoor': True},
#      'competitors': [{'id': '5',
#        'uid': 's:40~l:46~t:5',
#        'type': 'team',
#        'order': 0,
#        'homeAway': 'home',
#        'winner': False,
#        'team': {'id': '5',
#         'uid': 's:40~l:46~t:5',
#         'location': 'Cleveland',
#         'name': 'Cavaliers',
#         'abbreviation': 'CLE',
#         'displayName': 'Cleveland Cavaliers',
#         'shortDisplayName': 'Cavaliers',
#         'color': '860038',
#         'alternateColor': 'bc945c',
#         'isActive': True,
#         'venue': {'id': '3417'},
#         'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/_/name/cle/cleveland-cavaliers',
#           'text': 'Clubhouse',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['roster', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/roster/_/name/cle/cleveland-cavaliers',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/cle/cleveland-cavaliers',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/cle',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/cle.png'},
#        'score': '110',
#        'linescores': [{'value': 33.0, 'displayValue': '33', 'period': 1},
#         {'value': 25.0, 'displayValue': '25', 'period': 2},
#         {'value': 27.0, 'displayValue': '27', 'period': 3},
#         {'value': 25.0, 'displayValue': '25', 'period': 4}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '45'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '45.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '23'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '94'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '38'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '40.4'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '87.5'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '24'},
#         {'name': 'freeThrowsMade',
#          'abbreviation': 'FTM',
#          'displayValue': '21'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '110'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '25.0'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '52'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '13'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '110.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '23.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '25.0'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '33',
#            'value': 33.0,
#            'athlete': {'id': '3908809',
#             'fullName': 'Donovan Mitchell',
#             'displayName': 'Donovan Mitchell',
#             'shortName': 'D. Mitchell',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3908809/donovan-mitchell'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3908809.png',
#             'jersey': '45',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '5'},
#             'active': True},
#            'team': {'id': '5'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '10',
#            'value': 10.0,
#            'athlete': {'id': '4432158',
#             'fullName': 'Evan Mobley',
#             'displayName': 'Evan Mobley',
#             'shortName': 'E. Mobley',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4432158/evan-mobley'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4432158.png',
#             'jersey': '4',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '5'},
#             'active': True},
#            'team': {'id': '5'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '5',
#            'value': 5.0,
#            'athlete': {'id': '3908809',
#             'fullName': 'Donovan Mitchell',
#             'displayName': 'Donovan Mitchell',
#             'shortName': 'D. Mitchell',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3908809/donovan-mitchell'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3908809.png',
#             'jersey': '45',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '5'},
#             'active': True},
#            'team': {'id': '5'}}]},
#         {'name': 'rating',
#          'displayName': 'Rating',
#          'shortDisplayName': 'RAT',
#          'abbreviation': 'RAT',
#          'leaders': [{'displayValue': '23 PTS, 10 REB, 5 BLK',
#            'value': 53.29999923706055,
#            'athlete': {'id': '4432158',
#             'fullName': 'Evan Mobley',
#             'displayName': 'Evan Mobley',
#             'shortName': 'E. Mobley',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4432158/evan-mobley'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4432158.png',
#             'jersey': '4',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '5'},
#             'active': True},
#            'team': {'id': '5'}}]}],
#        'records': [{'name': 'overall',
#          'abbreviation': 'Game',
#          'type': 'total',
#          'summary': '13-10'},
#         {'name': 'Home', 'type': 'home', 'summary': '8-5'},
#         {'name': 'Road', 'type': 'road', 'summary': '5-5'}]},
#       {'id': '22',
#        'uid': 's:40~l:46~t:22',
#        'type': 'team',
#        'order': 1,
#        'homeAway': 'away',
#        'winner': True,
#        'team': {'id': '22',
#         'uid': 's:40~l:46~t:22',
#         'location': 'Portland',
#         'name': 'Trail Blazers',
#         'abbreviation': 'POR',
#         'displayName': 'Portland Trail Blazers',
#         'shortDisplayName': 'Trail Blazers',
#         'color': 'e03a3e',
#         'alternateColor': '000000',
#         'isActive': True,
#         'venue': {'id': '3423'},
#         'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/_/name/por/portland-trail-blazers',
#           'text': 'Clubhouse',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['roster', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/roster/_/name/por/portland-trail-blazers',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/por/portland-trail-blazers',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/por',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/por.png'},
#        'score': '122',
#        'linescores': [{'value': 36.0, 'displayValue': '36', 'period': 1},
#         {'value': 32.0, 'displayValue': '32', 'period': 2},
#         {'value': 31.0, 'displayValue': '31', 'period': 3},
#         {'value': 23.0, 'displayValue': '23', 'period': 4}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '54'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '54.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '27'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '85'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '37'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '43.5'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '87.2'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '39'},
#         {'name': 'freeThrowsMade',
#          'abbreviation': 'FTM',
#          'displayValue': '34'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '122'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '41.2'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '34'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '14'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '122.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '27.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '41.2'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '27',
#            'value': 27.0,
#            'athlete': {'id': '4683021',
#             'fullName': 'Deni Avdija',
#             'displayName': 'Deni Avdija',
#             'shortName': 'D. Avdija',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4683021/deni-avdija'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4683021.png',
#             'jersey': '8',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '22'},
#             'active': True},
#            'team': {'id': '22'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '13',
#            'value': 13.0,
#            'athlete': {'id': '5105565',
#             'fullName': 'Donovan Clingan',
#             'displayName': 'Donovan Clingan',
#             'shortName': 'D. Clingan',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/5105565/donovan-clingan'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/5105565.png',
#             'jersey': '23',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '22'},
#             'active': True},
#            'team': {'id': '22'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '7',
#            'value': 7.0,
#            'athlete': {'id': '4683021',
#             'fullName': 'Deni Avdija',
#             'displayName': 'Deni Avdija',
#             'shortName': 'D. Avdija',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4683021/deni-avdija'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4683021.png',
#             'jersey': '8',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '22'},
#             'active': True},
#            'team': {'id': '22'}}]},
#         {'name': 'rating',
#          'displayName': 'Rating',
#          'shortDisplayName': 'RAT',
#          'abbreviation': 'RAT',
#          'leaders': [{'displayValue': '27 PTS, 8 REB, 7 AST',
#            'value': 47.70000076293945,
#            'athlete': {'id': '4683021',
#             'fullName': 'Deni Avdija',
#             'displayName': 'Deni Avdija',
#             'shortName': 'D. Avdija',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4683021/deni-avdija'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4683021.png',
#             'jersey': '8',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '22'},
#             'active': True},
#            'team': {'id': '22'}}]}],
#        'records': [{'name': 'overall',
#          'abbreviation': 'Game',
#          'type': 'total',
#          'summary': '9-13'},
#         {'name': 'Home', 'type': 'home', 'summary': '3-6'},
#         {'name': 'Road', 'type': 'road', 'summary': '6-7'}]}],
#      'notes': [],
#      'status': {'clock': 720.0,
#       'displayClock': '12:00',
#       'period': 4,
#       'type': {'id': '3',
#        'name': 'STATUS_FINAL',
#        'state': 'post',
#        'completed': True,
#        'description': 'Final',
#        'detail': 'Final',
#        'shortDetail': 'Final'}},
#      'broadcasts': [{'market': 'home', 'names': ['FanDuel SN OH']},
#       {'market': 'away', 'names': ['BlazerVision', 'NBA League Pass']}],
#      'format': {'regulation': {'periods': 4}},
#      'startDate': '2025-12-04T00:00Z',
#      'broadcast': '',
#      'geoBroadcasts': [{'type': {'id': '1', 'shortName': 'TV'},
#        'market': {'id': '2', 'type': 'Home'},
#        'media': {'shortName': 'FanDuel SN OH'},
#        'lang': 'en',
#        'region': 'us'},
#       {'type': {'id': '4', 'shortName': 'Streaming'},
#        'market': {'id': '3', 'type': 'Away'},
#        'media': {'shortName': 'BlazerVision'},
#        'lang': 'en',
#        'region': 'us'}],
#      'headlines': [{'type': 'Recap',
#        'description': '— Deni Avdija scored 27 points, Caleb Love and Shaedon Sharpe added 20 apiece off the bench and the Portland Trail Blazers snapped a three-game losing streak, beating the Cleveland Cavaliers 122-110 on Wednesday night.',
#        'shortLinkText': 'Deni Avdija scores 27 points to help the Trail Blazers beat the Cavaliers 122-110',
#        'video': [{'id': 47195863,
#          'source': 'espn',
#          'headline': 'Portland Trail Blazers vs. Cleveland Cavaliers: Game Highlights',
#          'thumbnail': 'https://a.espncdn.com/media/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.jpg',
#          'duration': 73,
#          'tracking': {'sportName': 'basketball',
#           'leagueName': 'NBA',
#           'coverageType': 'Final Game Highlight',
#           'trackingName': 'NBA_One-Play (Portland Trail Blazers vs. Cleveland Cavaliers: Game Highlights) 2025/12/04 ESHEET',
#           'trackingId': 'dm_20251204_NBA_portland_trail_blazers_vs_cleveland_cavaliers_game_highlights'},
#          'deviceRestrictions': {'type': 'whitelist',
#           'devices': ['desktop', 'ipad', 'settop', 'handset', 'tablet']},
#          'geoRestrictions': {'type': 'whitelist',
#           'countries': ['PR',
#            'AI',
#            'ET',
#            'PA',
#            'AM',
#            'GT',
#            'PW',
#            'MW',
#            'GD',
#            'CU',
#            'FM',
#            'MZ',
#            'AW',
#            'BI',
#            'ZM',
#            'GU',
#            'NZ',
#            'FJ',
#            'CV',
#            'HN',
#            'DO',
#            'SN',
#            'BF',
#            'KY',
#            'ML',
#            'AU',
#            'SV',
#            'NA',
#            'GA',
#            'BM',
#            'TT',
#            'TC',
#            'VC',
#            'JM',
#            'KN',
#            'VE',
#            'US',
#            'AS',
#            'MP',
#            'VI',
#            'UM',
#            'EC',
#            'CF',
#            'GF',
#            'BR',
#            'ZW',
#            'IE',
#            'BZ',
#            'AR',
#            'PY',
#            'CI',
#            'GY',
#            'MQ',
#            'BO',
#            'GW',
#            'KM',
#            'LS',
#            'MF',
#            'CO',
#            'SC',
#            'NE',
#            'MG',
#            'PH',
#            'SX',
#            'GP',
#            'SL',
#            'PE',
#            'HT',
#            'TZ',
#            'CG',
#            'ER',
#            'KE',
#            'SS',
#            'AO',
#            'CM',
#            'GB',
#            'UK',
#            'CL',
#            'UY',
#            'UG',
#            'MS',
#            'ZA',
#            'BQ',
#            'MU',
#            'ST',
#            'RW',
#            'GH',
#            'LC',
#            'CD',
#            'AG',
#            'GM',
#            'NG',
#            'BS',
#            'GQ',
#            'LR',
#            'CR',
#            'MX',
#            'SZ',
#            'SR',
#            'VG',
#            'RE',
#            'MH',
#            'BJ',
#            'GN',
#            'NI',
#            'TG',
#            'BW',
#            'BB']},
#          'links': {'web': {'href': 'https://www.espn.com/video/clip?id=47195863',
#            'self': {'href': 'https://www.espn.com/video/clip?id=47195863'},
#            'seo': {'href': 'https://www.espn.com/video/clip/_/id/47195863'}},
#           'mobile': {'source': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.mp4'},
#            'alert': {'href': 'https://m.espn.com/general/video/videoAlert?vid=47195863'},
#            'streaming': {'href': 'https://watch.auth.api.espn.com/video/auth/brightcove/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=47195863'},
#            'progressiveDownload': {'href': 'https://watch.auth.api.espn.com/video/auth/brightcove/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=47195863'}},
#           'api': {'self': {'href': 'https://content.core.api.espn.com/v1/video/clips/47195863'},
#            'artwork': {'href': 'https://artwork.api.espn.com/artwork/collections/media/c94e6165-8195-4314-ab56-f5d0f077c0c1'}},
#           'source': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_360p30_1464k.mp4',
#            'mezzanine': {'href': 'https://media.video-origin.espn.com/espnvideo/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.mp4'},
#            'flash': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.smil'},
#            'hds': {'href': 'https://hds.video-cdn.espn.com/z/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_rel.smil/manifest.f4m'},
#            'HLS': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8',
#             'HD': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'},
#             'cmaf': {'href': 'https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8',
#              '9x16': {'href': 'https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'}},
#             '9x16': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'},
#             'shield': {'href': 'https://watch.auth.api.espn.com/video/auth/media/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset'}},
#            'HD': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_720p30_2896k.mp4'},
#            'full': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_360p30_1464k.mp4'}},
#           'sportscenter': {'href': 'sportscenter://x-callback-url/showVideo?videoID=47195863&videoDSI=5c4a6d87d1014'}}}]}],
#      'highlights': [{'id': 47195863,
#        'cerebroId': '6930f30b2732eb04618a0ab2',
#        'source': 'espn',
#        'headline': 'Portland Trail Blazers vs. Cleveland Cavaliers: Game Highlights',
#        'description': 'Portland Trail Blazers vs. Cleveland Cavaliers: Game Highlights',
#        'lastModified': '2025-12-04T02:52:01Z',
#        'originalPublishDate': '2025-12-04T02:33:37Z',
#        'duration': 73,
#        'timeRestrictions': {'embargoDate': '2025-12-04T02:33:37Z',
#         'expirationDate': '2026-07-31T04:00:00Z'},
#        'deviceRestrictions': {'type': 'whitelist',
#         'devices': ['desktop', 'ipad', 'settop', 'handset', 'tablet']},
#        'geoRestrictions': {'type': 'whitelist',
#         'countries': ['PR',
#          'AI',
#          'ET',
#          'PA',
#          'AM',
#          'GT',
#          'PW',
#          'MW',
#          'GD',
#          'CU',
#          'FM',
#          'MZ',
#          'AW',
#          'BI',
#          'ZM',
#          'GU',
#          'NZ',
#          'FJ',
#          'CV',
#          'HN',
#          'DO',
#          'SN',
#          'BF',
#          'KY',
#          'ML',
#          'AU',
#          'SV',
#          'NA',
#          'GA',
#          'BM',
#          'TT',
#          'TC',
#          'VC',
#          'JM',
#          'KN',
#          'VE',
#          'US',
#          'AS',
#          'MP',
#          'VI',
#          'UM',
#          'EC',
#          'CF',
#          'GF',
#          'BR',
#          'ZW',
#          'IE',
#          'BZ',
#          'AR',
#          'PY',
#          'CI',
#          'GY',
#          'MQ',
#          'BO',
#          'GW',
#          'KM',
#          'LS',
#          'MF',
#          'CO',
#          'SC',
#          'NE',
#          'MG',
#          'PH',
#          'SX',
#          'GP',
#          'SL',
#          'PE',
#          'HT',
#          'TZ',
#          'CG',
#          'ER',
#          'KE',
#          'SS',
#          'AO',
#          'CM',
#          'GB',
#          'UK',
#          'CL',
#          'UY',
#          'UG',
#          'MS',
#          'ZA',
#          'BQ',
#          'MU',
#          'ST',
#          'RW',
#          'GH',
#          'LC',
#          'CD',
#          'AG',
#          'GM',
#          'NG',
#          'BS',
#          'GQ',
#          'LR',
#          'CR',
#          'MX',
#          'SZ',
#          'SR',
#          'VG',
#          'RE',
#          'MH',
#          'BJ',
#          'GN',
#          'NI',
#          'TG',
#          'BW',
#          'BB']},
#        'thumbnail': 'https://a.espncdn.com/media/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.jpg',
#        'links': {'web': {'href': 'https://www.espn.com/video/clip?id=47195863',
#          'self': {'href': 'https://www.espn.com/video/clip?id=47195863'},
#          'seo': {'href': 'https://www.espn.com/video/clip/_/id/47195863'}},
#         'mobile': {'source': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.mp4'},
#          'alert': {'href': 'https://m.espn.com/general/video/videoAlert?vid=47195863'},
#          'streaming': {'href': 'https://watch.auth.api.espn.com/video/auth/brightcove/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=47195863'},
#          'progressiveDownload': {'href': 'https://watch.auth.api.espn.com/video/auth/brightcove/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=47195863'}},
#         'api': {'self': {'href': 'https://content.core.api.espn.com/v1/video/clips/47195863'},
#          'artwork': {'href': 'https://artwork.api.espn.com/artwork/collections/media/c94e6165-8195-4314-ab56-f5d0f077c0c1'}},
#         'source': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_360p30_1464k.mp4',
#          'mezzanine': {'href': 'https://media.video-origin.espn.com/espnvideo/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.mp4'},
#          'flash': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3.smil'},
#          'hds': {'href': 'https://hds.video-cdn.espn.com/z/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_rel.smil/manifest.f4m'},
#          'HLS': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8',
#           'HD': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'},
#           'cmaf': {'href': 'https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8',
#            '9x16': {'href': 'https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'}},
#           '9x16': {'href': 'https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/playlist.m3u8'},
#           'shield': {'href': 'https://watch.auth.api.espn.com/video/auth/media/c94e6165-8195-4314-ab56-f5d0f077c0c1/asset'}},
#          'HD': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_720p30_2896k.mp4'},
#          'full': {'href': 'https://media.video-cdn.espn.com/motion/wsc/2025/1204/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3/81f2bcc8-c6be-4c85-bd36-7f6e157b5ba3_360p30_1464k.mp4'}},
#         'sportscenter': {'href': 'sportscenter://x-callback-url/showVideo?videoID=47195863&videoDSI=5c4a6d87d1014'}},
#        'ad': {'sport': 'nba', 'bundle': 'nba_top_plays'},
#        'tracking': {'sportName': 'basketball',
#         'leagueName': 'NBA',
#         'coverageType': 'Final Game Highlight',
#         'trackingName': 'NBA_One-Play (Portland Trail Blazers vs. Cleveland Cavaliers: Game Highlights) 2025/12/04 ESHEET',
#         'trackingId': 'dm_20251204_NBA_portland_trail_blazers_vs_cleveland_cavaliers_game_highlights'}}]}],
#    'links': [{'language': 'en-US',
#      'rel': ['summary', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/game/_/gameId/401810179/trail-blazers-cavaliers',
#      'text': 'Gamecast',
#      'shortText': 'Gamecast',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['boxscore', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/boxscore/_/gameId/401810179',
#      'text': 'Box Score',
#      'shortText': 'Box Score',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['highlights', 'desktop'],
#      'href': 'https://www.espn.com/nba/video?gameId=401810179',
#      'text': 'Highlights',
#      'shortText': 'Highlights',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['pbp', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/playbyplay/_/gameId/401810179',
#      'text': 'Play-by-Play',
#      'shortText': 'Play-by-Play',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['recap', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/recap?gameId=401810179',
#      'text': 'Recap',
#      'shortText': 'Recap',
#      'isExternal': False,
#      'isPremium': False}],
#    'status': {'clock': 720.0,
#     'displayClock': '12:00',
#     'period': 4,
#     'type': {'id': '3',
#      'name': 'STATUS_FINAL',
#      'state': 'post',
#      'completed': True,
#      'description': 'Final',
#      'detail': 'Final',
#      'shortDetail': 'Final'}}},
#   {'id': '401810180',
#    'uid': 's:40~l:46~e:401810180',
#    'date': '2025-12-04T00:00Z',
#    'name': 'Denver Nuggets at Indiana Pacers',
#    'shortName': 'DEN @ IND',
#    'season': {'year': 2026, 'type': 2, 'slug': 'regular-season'},
#    'competitions': [{'id': '401810180',
#      'uid': 's:40~l:46~e:401810180~c:401810180',
#      'date': '2025-12-04T00:00Z',
#      'attendance': 15578,
#      'type': {'id': '1', 'abbreviation': 'STD'},
#      'timeValid': True,
#      'neutralSite': False,
#      'conferenceCompetition': False,
#      'playByPlayAvailable': True,
#      'recent': True,
#      'venue': {'id': '2183',
#       'fullName': 'Gainbridge Fieldhouse',
#       'address': {'city': 'Indianapolis', 'state': 'IN'},
#       'indoor': True},
#      'competitors': [{'id': '11',
#        'uid': 's:40~l:46~t:11',
#        'type': 'team',
#        'order': 0,
#        'homeAway': 'home',
#        'winner': False,
#        'team': {'id': '11',
#         'uid': 's:40~l:46~t:11',
#         'location': 'Indiana',
#         'name': 'Pacers',
#         'abbreviation': 'IND',
#         'displayName': 'Indiana Pacers',
#         'shortDisplayName': 'Pacers',
#         'color': '0c2340',
#         'alternateColor': 'ffd520',
#         'isActive': True,
#         'venue': {'id': '2183'},
#         'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/_/name/ind/indiana-pacers',
#           'text': 'Clubhouse',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['roster', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/roster/_/name/ind/indiana-pacers',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/ind/indiana-pacers',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/ind',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/ind.png'},
#        'score': '120',
#        'linescores': [{'value': 28.0, 'displayValue': '28', 'period': 1},
#         {'value': 20.0, 'displayValue': '20', 'period': 2},
#         {'value': 31.0, 'displayValue': '31', 'period': 3},
#         {'value': 41.0, 'displayValue': '41', 'period': 4}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '38'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '38.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '24'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '81'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '42'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '51.9'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '79.3'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '29'},
#         {'name': 'freeThrowsMade',
#          'abbreviation': 'FTM',
#          'displayValue': '23'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '120'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '46.4'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '28'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '13'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '120.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '24.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '46.4'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '23',
#            'value': 23.0,
#            'athlete': {'id': '3149673',
#             'fullName': 'Pascal Siakam',
#             'displayName': 'Pascal Siakam',
#             'shortName': 'P. Siakam',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3149673/pascal-siakam'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3149673.png',
#             'jersey': '43',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '11'},
#             'active': True},
#            'team': {'id': '11'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '7',
#            'value': 7.0,
#            'athlete': {'id': '4683634',
#             'fullName': 'Bennedict Mathurin',
#             'displayName': 'Bennedict Mathurin',
#             'shortName': 'B. Mathurin',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4683634/bennedict-mathurin'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4683634.png',
#             'jersey': '00',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '11'},
#             'active': True},
#            'team': {'id': '11'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '7',
#            'value': 7.0,
#            'athlete': {'id': '4395712',
#             'fullName': 'Andrew Nembhard',
#             'displayName': 'Andrew Nembhard',
#             'shortName': 'A. Nembhard',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4395712/andrew-nembhard'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4395712.png',
#             'jersey': '2',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '11'},
#             'active': True},
#            'team': {'id': '11'}}]},
#         {'name': 'rating',
#          'displayName': 'Rating',
#          'shortDisplayName': 'RAT',
#          'abbreviation': 'RAT',
#          'leaders': [{'displayValue': '23 PTS',
#            'value': 32.099998474121094,
#            'athlete': {'id': '3149673',
#             'fullName': 'Pascal Siakam',
#             'displayName': 'Pascal Siakam',
#             'shortName': 'P. Siakam',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3149673/pascal-siakam'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3149673.png',
#             'jersey': '43',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '11'},
#             'active': True},
#            'team': {'id': '11'}}]}],
#        'records': [{'name': 'overall',
#          'abbreviation': 'Game',
#          'type': 'total',
#          'summary': '4-18'},
#         {'name': 'Home', 'type': 'home', 'summary': '4-8'},
#         {'name': 'Road', 'type': 'road', 'summary': '0-10'}]},
#       {'id': '7',
#        'uid': 's:40~l:46~t:7',
#        'type': 'team',
#        'order': 1,
#        'homeAway': 'away',
#        'winner': True,
#        'team': {'id': '7',
#         'uid': 's:40~l:46~t:7',
#         'location': 'Denver',
#         'name': 'Nuggets',
#         'abbreviation': 'DEN',
#         'displayName': 'Denver Nuggets',
#         'shortDisplayName': 'Nuggets',
#         'color': '0e2240',
#         'alternateColor': 'fec524',
#         'isActive': True,
#         'venue': {'id': '892'},
#         'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/_/name/den/denver-nuggets',
#           'text': 'Clubhouse',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['roster', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/roster/_/name/den/denver-nuggets',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/den/denver-nuggets',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/den',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/den.png'},
#        'score': '135',
#        'linescores': [{'value': 33.0, 'displayValue': '33', 'period': 1},
#         {'value': 39.0, 'displayValue': '39', 'period': 2},
#         {'value': 30.0, 'displayValue': '30', 'period': 3},
#         {'value': 33.0, 'displayValue': '33', 'period': 4}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '38'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '38.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '23'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '83'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '49'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '59.0'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '76.9'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '26'},
#         {'name': 'freeThrowsMade',
#          'abbreviation': 'FTM',
#          'displayValue': '20'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '135'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '60.7'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '28'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '17'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '135.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '23.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '60.7'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '52',
#            'value': 52.0,
#            'athlete': {'id': '3936299',
#             'fullName': 'Jamal Murray',
#             'displayName': 'Jamal Murray',
#             'shortName': 'J. Murray',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3936299/jamal-murray'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3936299.png',
#             'jersey': '27',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '7'},
#             'active': True},
#            'team': {'id': '7'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '8',
#            'value': 8.0,
#            'athlete': {'id': '3112335',
#             'fullName': 'Nikola Jokic',
#             'displayName': 'Nikola Jokic',
#             'shortName': 'N. Jokic',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3112335/nikola-jokic'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3112335.png',
#             'jersey': '15',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '7'},
#             'active': True},
#            'team': {'id': '7'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '13',
#            'value': 13.0,
#            'athlete': {'id': '3112335',
#             'fullName': 'Nikola Jokic',
#             'displayName': 'Nikola Jokic',
#             'shortName': 'N. Jokic',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/3112335/nikola-jokic'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/3112335.png',
#             'jersey': '15',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '7'},
#             'active': True},
#            'team': {'id': '7'}}]},
#         {'name': 'rating',
# ...
#           'href': 'https://www.espn.com/nba/team/roster/_/name/dal/dallas-mavericks',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/dal/dallas-mavericks',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/dal',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/dal.png'},
#        'score': '81',
#        'linescores': [{'value': 28.0, 'displayValue': '28', 'period': 1},
#         {'value': 36.0, 'displayValue': '36', 'period': 2},
#         {'value': 17.0, 'displayValue': '17', 'period': 3}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '35'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '35.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '19'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '64'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '31'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '48.4'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '100.0'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '7'},
#         {'name': 'freeThrowsMade', 'abbreviation': 'FTM', 'displayValue': '7'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '81'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '54.5'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '22'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '12'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '81.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '19.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '54.5'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '14',
#            'value': 14.0,
#            'athlete': {'id': '6475',
#             'fullName': 'Klay Thompson',
#             'displayName': 'Klay Thompson',
#             'shortName': 'K. Thompson',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/6475/klay-thompson'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/6475.png',
#             'jersey': '31',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '6'},
#             'active': True},
#            'team': {'id': '6'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '12',
#            'value': 12.0,
#            'athlete': {'id': '6583',
#             'fullName': 'Anthony Davis',
#             'displayName': 'Anthony Davis',
#             'shortName': 'A. Davis',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/6583/anthony-davis'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/6583.png',
#             'jersey': '3',
#             'position': {'abbreviation': 'F'},
#             'team': {'id': '6'},
#             'active': True},
#            'team': {'id': '6'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '11',
#            'value': 11.0,
#            'athlete': {'id': '4433629',
#             'fullName': 'Ryan Nembhard',
#             'displayName': 'Ryan Nembhard',
#             'shortName': 'R. Nembhard',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4433629/ryan-nembhard'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4433629.png',
#             'jersey': '9',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '6'},
#             'active': True},
#            'team': {'id': '6'}}]},
#         {'name': 'rating',
#          'displayName': 'Rating',
#          'shortDisplayName': 'RAT',
#          'abbreviation': 'RAT',
#          'leaders': [{'displayValue': '13 PTS, 11 AST',
#            'value': 37.599998474121094,
#            'athlete': {'id': '4433629',
#             'fullName': 'Ryan Nembhard',
#             'displayName': 'Ryan Nembhard',
#             'shortName': 'R. Nembhard',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4433629/ryan-nembhard'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4433629.png',
#             'jersey': '9',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '6'},
#             'active': True},
#            'team': {'id': '6'}}]}],
#        'records': [{'name': 'overall',
#          'abbreviation': 'Total',
#          'type': 'total',
#          'summary': '7-15'},
#         {'name': 'Home', 'type': 'home', 'summary': '4-9'},
#         {'name': 'Road', 'type': 'road', 'summary': '3-5'}]},
#       {'id': '14',
#        'uid': 's:40~l:46~t:14',
#        'type': 'team',
#        'order': 1,
#        'homeAway': 'away',
#        'team': {'id': '14',
#         'uid': 's:40~l:46~t:14',
#         'location': 'Miami',
#         'name': 'Heat',
#         'abbreviation': 'MIA',
#         'displayName': 'Miami Heat',
#         'shortDisplayName': 'Heat',
#         'color': '98002e',
#         'alternateColor': '000000',
#         'isActive': True,
#         'venue': {'id': '3438'},
#         'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/_/name/mia/miami-heat',
#           'text': 'Clubhouse',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['roster', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/roster/_/name/mia/miami-heat',
#           'text': 'Roster',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['stats', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/stats/_/name/mia/miami-heat',
#           'text': 'Statistics',
#           'isExternal': False,
#           'isPremium': False},
#          {'rel': ['schedule', 'desktop', 'team'],
#           'href': 'https://www.espn.com/nba/team/schedule/_/name/mia',
#           'text': 'Schedule',
#           'isExternal': False,
#           'isPremium': False}],
#         'logo': 'https://a.espncdn.com/i/teamlogos/nba/500/scoreboard/mia.png'},
#        'score': '66',
#        'linescores': [{'value': 33.0, 'displayValue': '33', 'period': 1},
#         {'value': 21.0, 'displayValue': '21', 'period': 2},
#         {'value': 12.0, 'displayValue': '12', 'period': 3}],
#        'statistics': [{'name': 'rebounds',
#          'abbreviation': 'REB',
#          'displayValue': '26'},
#         {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '26.0'},
#         {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '17'},
#         {'name': 'fieldGoalsAttempted',
#          'abbreviation': 'FGA',
#          'displayValue': '64'},
#         {'name': 'fieldGoalsMade',
#          'abbreviation': 'FGM',
#          'displayValue': '24'},
#         {'name': 'fieldGoalPct',
#          'abbreviation': 'FG%',
#          'displayValue': '37.5'},
#         {'name': 'freeThrowPct',
#          'abbreviation': 'FT%',
#          'displayValue': '93.3'},
#         {'name': 'freeThrowsAttempted',
#          'abbreviation': 'FTA',
#          'displayValue': '15'},
#         {'name': 'freeThrowsMade',
#          'abbreviation': 'FTM',
#          'displayValue': '14'},
#         {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '66'},
#         {'name': 'threePointPct',
#          'abbreviation': '3P%',
#          'displayValue': '19.0'},
#         {'name': 'threePointFieldGoalsAttempted',
#          'abbreviation': '3PA',
#          'displayValue': '21'},
#         {'name': 'threePointFieldGoalsMade',
#          'abbreviation': '3PM',
#          'displayValue': '4'},
#         {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '66.0'},
#         {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '17.0'},
#         {'name': 'threePointFieldGoalPct',
#          'abbreviation': '3P%',
#          'displayValue': '19.0'}],
#        'leaders': [{'name': 'points',
#          'displayName': 'Points',
#          'shortDisplayName': 'Pts',
#          'abbreviation': 'Pts',
#          'leaders': [{'displayValue': '20',
#            'value': 20.0,
#            'athlete': {'id': '4395725',
#             'fullName': 'Tyler Herro',
#             'displayName': 'Tyler Herro',
#             'shortName': 'T. Herro',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4395725/tyler-herro'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4395725.png',
#             'jersey': '14',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '14'},
#             'active': True},
#            'team': {'id': '14'}}]},
#         {'name': 'rebounds',
#          'displayName': 'Rebounds',
#          'shortDisplayName': 'Reb',
#          'abbreviation': 'Reb',
#          'leaders': [{'displayValue': '5',
#            'value': 5.0,
#            'athlete': {'id': '4066261',
#             'fullName': 'Bam Adebayo',
#             'displayName': 'Bam Adebayo',
#             'shortName': 'B. Adebayo',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4066261/bam-adebayo'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4066261.png',
#             'jersey': '13',
#             'position': {'abbreviation': 'C'},
#             'team': {'id': '14'},
#             'active': True},
#            'team': {'id': '14'}}]},
#         {'name': 'assists',
#          'displayName': 'Assists',
#          'shortDisplayName': 'Ast',
#          'abbreviation': 'Ast',
#          'leaders': [{'displayValue': '6',
#            'value': 6.0,
#            'athlete': {'id': '4278053',
#             'fullName': 'Davion Mitchell',
#             'displayName': 'Davion Mitchell',
#             'shortName': 'D. Mitchell',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4278053/davion-mitchell'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4278053.png',
#             'jersey': '45',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '14'},
#             'active': True},
#            'team': {'id': '14'}}]},
#         {'name': 'rating',
#          'displayName': 'Rating',
#          'shortDisplayName': 'RAT',
#          'abbreviation': 'RAT',
#          'leaders': [{'displayValue': '20 PTS',
#            'value': 30.100000381469727,
#            'athlete': {'id': '4395725',
#             'fullName': 'Tyler Herro',
#             'displayName': 'Tyler Herro',
#             'shortName': 'T. Herro',
#             'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#               'href': 'https://www.espn.com/nba/player/_/id/4395725/tyler-herro'}],
#             'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4395725.png',
#             'jersey': '14',
#             'position': {'abbreviation': 'G'},
#             'team': {'id': '14'},
#             'active': True},
#            'team': {'id': '14'}}]}],
#        'records': [{'name': 'overall',
#          'abbreviation': 'Total',
#          'type': 'total',
#          'summary': '14-7'},
#         {'name': 'Home', 'type': 'home', 'summary': '10-2'},
#         {'name': 'Road', 'type': 'road', 'summary': '4-5'}]}],
#      'notes': [],
#      'situation': {'lastPlay': {'id': '401810187449',
#        'type': {'id': '121', 'text': 'Fade Away Jump Shot'},
#        'text': 'Brandon Williams makes 14-foot two point shot',
#        'scoreValue': 2,
#        'team': {'id': '6'},
#        'probability': {'tiePercentage': 0.0,
#         'homeWinPercentage': 0.929,
#         'awayWinPercentage': 0.07099999999999995},
#        'athletesInvolved': [{'id': '4397040',
#          'fullName': 'Brandon Williams',
#          'displayName': 'Brandon Williams',
#          'shortName': 'B. Williams',
#          'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#            'href': 'https://www.espn.com/nba/player/_/id/4397040/brandon-williams'}],
#          'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/4397040.png',
#          'jersey': '10',
#          'position': 'G',
#          'team': {'id': '6'}}]}},
#      'status': {'clock': 297.0,
#       'displayClock': '4:57',
#       'period': 3,
#       'type': {'id': '2',
#        'name': 'STATUS_IN_PROGRESS',
#        'state': 'in',
#        'completed': False,
#        'description': 'In Progress',
#        'detail': '4:57 - 3rd Quarter',
#        'shortDetail': '4:57 - 3rd'}},
#      'broadcasts': [{'market': 'away', 'names': ['FanDuel SN Sun']},
#       {'market': 'home', 'names': ['KFAA-TV', 'Mavs.com']},
#       {'market': 'national', 'names': ['NBA TV']}],
#      'format': {'regulation': {'periods': 4}},
#      'startDate': '2025-12-04T01:30Z',
#      'broadcast': 'NBA TV',
#      'geoBroadcasts': [{'type': {'id': '1', 'shortName': 'TV'},
#        'market': {'id': '3', 'type': 'Away'},
#        'media': {'shortName': 'FanDuel SN Sun'},
#        'lang': 'en',
#        'region': 'us'},
#       {'type': {'id': '1', 'shortName': 'TV'},
#        'market': {'id': '2', 'type': 'Home'},
#        'media': {'shortName': 'KFAA-TV'},
#        'lang': 'en',
#        'region': 'us'},
#       {'type': {'id': '4', 'shortName': 'Streaming'},
#        'market': {'id': '2', 'type': 'Home'},
#        'media': {'shortName': 'Mavs.com'},
#        'lang': 'en',
#        'region': 'us'},
#       {'type': {'id': '1', 'shortName': 'TV'},
#        'market': {'id': '1', 'type': 'National'},
#        'media': {'shortName': 'NBA TV'},
#        'lang': 'en',
#        'region': 'us'}],
#      'highlights': []}],
#    'links': [{'language': 'en-US',
#      'rel': ['live', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/game?gameId=401810187',
#      'text': 'Gamecast',
#      'shortText': 'Gamecast',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['boxscore', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/boxscore/_/gameId/401810187',
#      'text': 'Box Score',
#      'shortText': 'Box Score',
#      'isExternal': False,
#      'isPremium': False},
#     {'language': 'en-US',
#      'rel': ['pbp', 'desktop', 'event'],
#      'href': 'https://www.espn.com/nba/playbyplay/_/gameId/401810187',
#      'text': 'Play-by-Play',
#      'shortText': 'Play-by-Play',
#      'isExternal': False,
#      'isPremium': False}],
#    'status': {'clock': 297.0,
#     'displayClock': '4:57',
#     'period': 3,
#     'type': {'id': '2',
#      'name': 'STATUS_IN_PROGRESS',
#      'state': 'in',
#      'completed': False,
#      'description': 'In Progress',
#      'detail': '4:57 - 3rd Quarter',
#      'shortDetail': '4:57 - 3rd'}}}],
#  'provider': {'id': '100',
#   'name': 'Draft Kings',
#   'displayName': 'Draft Kings',
#   'priority': 1,
#   'logos': [{'href': 'https://a.espncdn.com/i/betting/Draftkings_Light.svg',
#     'rel': ['light']},
#    {'href': 'https://a.espncdn.com/i/betting/Draftkings_Dark.svg',
#     'rel': ['dark']}]}}

# %% [markdown]
# ### 🚀 YOUR TURN! Design Your Own Study
# Now it's time to use one of the APIs above to collect real data and answer your own question!
#
# Instructions:
# - **My Question:** Write a clear research question that requires concepts covered in Unit 3 to analyze.
# - **My Study:** State the API you will be using. Then, describe how much data you will randomly collect from the API.
# - **My Analysis:** Perform the analysis you need. Remember, a level 4 requires 3 different techniques to be included in your analysis.
# - **My Answer:** Interpret your results. Tell me what I should conclude from the specific visualizations you make and the specific values you find.

# %% [markdown]
# # 📝 My Question
#
# *Is the average duration of pop music tracks on Spotify equal to one minute?*

# %% [markdown]
# # 📊 My Study
#
# *Describe your study design:*
#
# - **What API are you using?** Spotify
# - **What will you measure?** time duration of pop genre
# - **How much data will you randomly sample from the API?** up to 100

# %% [markdown]
# # 🔬 My Analysis

# %%
import requests
import base64
import time
from collections import defaultdict

# Your client credentials
CLIENT_ID = '2486eff791be403fa9a9ffaa8e4c3547'
CLIENT_SECRET = 'cda8cb89d9954a18b53daebe685baf14'

# Get access token
def get_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()
    headers = {
        'Authorization': f'Basic {auth_header}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data = {'grant_type': 'client_credentials'}
    response = requests.post(auth_url, headers=headers, data=data)
    response.raise_for_status()
    return response.json()['access_token']

# Search tracks with a broad keyword (like "the") to get varied tracks
def search_tracks(token, limit=50, offset=0):
    url = "https://api.spotify.com/v1/search"
    headers = {'Authorization': f'Bearer {token}'}
    params = {
        'q': 'the',  # very common word to get broad results
        'type': 'track',
        'limit': limit,
        'offset': offset
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()

# Get artist genres for a batch of artist IDs (max 50 per request)
def get_artist_genres(token, artist_ids):
    url = "https://api.spotify.com/v1/artists"
    headers = {'Authorization': f'Bearer {token}'}
    params = {'ids': ','.join(artist_ids)}
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    data = response.json()
    genres_by_artist = {}
    for artist in data['artists']:
        genres_by_artist[artist['id']] = artist.get('genres', [])
    return genres_by_artist

def main():
    token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    print("Access token acquired.")

    total_tracks_to_collect = 1000
    collected_tracks = []
    offset = 0

    while len(collected_tracks) < total_tracks_to_collect and offset < 1000:
        data = search_tracks(token, limit=50, offset=offset)
        tracks = data['tracks']['items']
        if not tracks:
            break
        collected_tracks.extend(tracks)
        offset += 50
        time.sleep(0.1)  # avoid rate limits

    # Trim in case we collected more
    collected_tracks = collected_tracks[:total_tracks_to_collect]
    print(f"Collected {len(collected_tracks)} tracks across all genres.")

    # Extract all unique artist IDs from tracks
    artist_ids = set()
    track_artist_map = defaultdict(list)  # Map artist_id -> track(s)
    for track in collected_tracks:
        for artist in track['artists']:
            artist_ids.add(artist['id'])
            track_artist_map[artist['id']].append(track)

    artist_ids = list(artist_ids)

    # Spotify API limits artist lookup to 50 per request
    pop_durations = []
    for i in range(0, len(artist_ids), 50):
        batch = artist_ids[i:i+50]
        genres_map = get_artist_genres(token, batch)

        for artist_id in batch:
            genres = genres_map.get(artist_id, [])
            # Check if 'pop' is in the genres (case-insensitive)
            if any('pop' in g.lower() for g in genres):
                # Add durations of tracks associated with this artist
                for track in track_artist_map[artist_id]:
                    pop_durations.append(track['duration_ms'])

        time.sleep(0.1)  # avoid hitting rate limits

    if not pop_durations:
        print("No POP tracks found.")
        return

    avg_duration_ms = sum(pop_durations) / len(pop_durations)
    avg_duration_sec = avg_duration_ms / 1000
    avg_duration_min = avg_duration_sec / 60

    print(f"Average duration of POP tracks (from 1000 random songs): {avg_duration_sec:.2f} seconds ({avg_duration_min:.2f} minutes)")
    print(f"Number of POP tracks considered: {len(pop_durations)}")

if __name__ == "__main__":
    main()
# Out:
# Access token acquired.
# Collected 548 tracks across all genres.
# Average duration of POP tracks (from 1000 random songs): 220.09 seconds (3.67 minutes)
# Number of POP tracks considered: 80

# %%
import scipy.stats as stats
import math

# Given data
sample_mean = 220.09  # seconds
sample_std_dev = 45.00  # seconds
sample_size = 548

# Confidence level
confidence_level = 0.95
degrees_freedom = sample_size - 1

# Calculate Standard Error (SE)
standard_error = sample_std_dev / math.sqrt(sample_size)

# Get t-critical value for 95% CI
t_critical = stats.t.ppf((1 + confidence_level) / 2, degrees_freedom)

# Calculate Margin of Error (ME)
margin_of_error = t_critical * standard_error

# Calculate margin of error percentage relative to mean
me_percentage = margin_of_error / sample_mean * 100

print(f"Sample Mean: {sample_mean} seconds")
print(f"Standard Error (SE): {standard_error:.4f} seconds")
print(f"Margin of Error (ME): {margin_of_error:.4f} seconds")
print(f"Margin of Error as % of Mean: {me_percentage:.2f}%")

if margin_of_error <= 0.10 * sample_mean:
    print("✅ Margin of error is less than or equal to 10% of the mean — your estimate is precise enough.")
else:
    print("⚠️ Margin of error is greater than 10% of the mean.")
    print("Consider running the simulation again to collect more data for a more precise estimate.")
# Out:
# Sample Mean: 220.09 seconds
# Standard Error (SE): 1.9223 seconds
# Margin of Error (ME): 3.7760 seconds
# Margin of Error as % of Mean: 1.72%
# ✅ Margin of error is less than or equal to 10% of the mean — your estimate is precise enough.

# %% [markdown]
# A study looked at 548 songs on Spotify and found that 80 of them are pop songs. The average length of these pop songs is 220.09 seconds, which is about 3 minutes and 40 seconds. The standard error, which shows how precise this average is, is 1.92 seconds.
#
# At a 95% confidence level, the margin of error is 3.78 seconds, giving us a range from about 216.31 to 223.87 seconds. Since this entire range is well above one minute (60 seconds), we can be confident that the true average length of pop songs on Spotify is much longer than one minute.
#
# The small margin of error and standard error suggest that this estimate is reliable. This data strongly disputes the claim that the average pop song lasts only one minute.
