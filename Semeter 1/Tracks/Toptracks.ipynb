# %% [markdown]
# # What is the least popular genre in the U.S. Top Tracks in ? What was the less listen genre in the whole world?
# is going to be observational and need's to be from the whole population, it was collected by Mrs.Spindt from Spotify records this was selected since it's related to my question and show some extra information. Mrs.Spindt search and ask to AI looking for information about the tracks of the world and U.S. by looking for Spotify records of 2024 and Wikipedia , if she was distracted and didn't double check or the place where she was looking up was the wrong one  there could be an irregularity and something can be put in the wrong place. There is also another problem it depends in which genre I'm choosing the information since if I choose AI genre it give me more specif but it would skip other genres that I need and the Wiki genre will show me all but is too long and the names are similar and don't put together, for example pop don't go with pop rock. Once I try to summarize it make that pop and pop rock be together making a change and being less diverse. in the process of making the pie charts there is many genres making that it be less visible what is what making that hard to read but once changed it may skip some percentages or showing wrong percentage of the original and even the person who see it first may think that the other that are put together be the same one when really they are small percentages added.

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("usa.csv")

# Create frequency table using "Wiki Genre"
genre_freq = df["Wiki Genre"].value_counts().reset_index()
genre_freq.columns = ["Genre", "Frequency"]

# Print the frequency table
print(genre_freq)
# Out:
#                                                 Genre  Frequency
# 0                                             Country          4
# 1                                         Country pop          4
# 2                                            Pop rock          2
# 3                                                Folk          2
# 4                           West Coast hip-hop, hyphy          1
# 5                          Pop, funk, dance, nu-disco          1
# 6                          Synth-pop, new wave, dance          1
# 7                          R&B, electro-funk, hip hop          1
# 8                                         Country rap          1
# 9                                       New wave, pop          1
# 10                Blue-eyed soul, pop rock, funk rock          1
# 11  Pop, disco-pop, synth-pop, country pop, altern...          1
# 12                                               Soul          1
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("usa.csv")

# Create frequency table using "AI Genre"
genre_freq = df["AI Genre"].value_counts().reset_index()
genre_freq.columns = ["Genre", "Frequency"]

# Print the frequency table
print(genre_freq)
# Out:
#               Genre  Frequency
# 0               Pop         16
# 1           Country         11
# 2           Hip-Hop          9
# 3               R&B          5
# 4        Indie Folk          3
# 5  Alternative Rock          3
# 6          Pop Rock          1
# 7        Indie Rock          1
# 8   Alternative Pop          1

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("global.csv")

# Create frequency table using "Wiki Genre"
genre_freq = df["Wiki Genre"].value_counts().reset_index()
genre_freq.columns = ["Genre", "Frequency"]

# Print the frequency table
print(genre_freq)
# Out:
#                                                 Genre  Frequency
# 0                                           Reggaeton          3
# 1                                         Country pop          2
# 2                                            Pop rock          1
# 3                                       New wave, pop          1
# 4                                                Soul          1
# 5                          Pop, funk, dance, nu-disco          1
# 6                 Blue-eyed soul, pop rock, funk rock          1
# 7                                                 R&B          1
# 8             Electro, pop, synth-pop, industrial pop          1
# 9                                 Pop-soul, soft rock          1
# 10                         Alternative pop, dark wave          1
# 11                      Synth-pop, Europop, power pop          1
# 12  Pop, disco-pop, synth-pop, country pop, altern...          1
# ...

# %%
freq = {
    "Genre" : ["POP", "Rap", "Country"];
    "Frequency" : []
}

# %%
import pandas as pd
 
df = pd.read_csv("global.csv")

wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

all_genres = [genre for sublist in wiki_genres for genre in sublist]

wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

print(wiki_genre_freq)
# Out:
#          Genre  Frequency
# 0          R&B         11
# 1          pop          8
# 2          Pop          5
# 3    Synth-pop          5
# 4     new wave          4
# ..         ...        ...
# 67      lounge          1
# 68  Indie rock          1
# 69        Folk          1
# 70   Folk rock          1
# 71   disco-pop          1
#
# [72 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_csv("global.csv")

wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

all_genres = [g.lower() for g in all_genres]

wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Print frequency table
print(wiki_genre_freq)
# Out:
#            Genre  Frequency
# 0            pop         18
# 1            r&b         11
# 2      synth-pop          9
# 3            new          5
# 4    alternative          5
# 5          indie          5
# 6        country          5
# 7        electro          4
# 8            hip          3
# 9      reggaeton          3
# 10          funk          3
# 11     dance-pop          2
# 12         dance          2
# 13     downtempo          2
# 14          folk          2
# 15     blue-eyed          1
# 16       baroque          1
# 17          soul          1
# 18      nu-disco          1
# 19         power          1
# 20       europop          1
# 21          dark          1
# 22          soft          1
# 23    industrial          1
# 24      pop-soul          1
# 25         yacht          1
# 26     disco-pop          1
# 27         hyphy          1
# 28          west          1
# 29  electro-funk          1
# 30        lounge          1
# 31        gothic          1
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("usa.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase so "Pop" and "pop" count as the same
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Print frequency table
print(wiki_genre_freq)
# Out:
#            Genre  Frequency
# 0            pop         18
# 1        country         12
# 2            r&b          8
# 3      synth-pop          7
# 4    alternative          5
# 5          dance          4
# 6            new          4
# 7        electro          4
# 8      dance-pop          4
# 9           folk          3
# 10           hip          3
# 11          trap          3
# 12          funk          2
# 13         indie          2
# 14     downtempo          2
# 15          soft          2
# 16     blue-eyed          1
# 17     disco-pop          1
# 18         hyphy          1
# 19          west          1
# 20      nu-disco          1
# 21  electro-funk          1
# 22         yacht          1
# 23       baroque          1
# 24          hick          1
# 25       hip-hop          1
# 26      hardcore          1
# 27        gothic          1
# 28    industrial          1
# 29       pop-rap          1
# 30          soul          1
# 31        lounge          1
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("global.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Plot horizontal bar chart
plt.figure(figsize=(10,12))
sns.barplot(data=wiki_genre_freq, y="Genre", x="Frequency", palette="mako")

# Labels and title
plt.title("Frequency of Genres (first word only)", fontsize=14)
plt.xlabel("Frequency")
plt.ylabel("Genre")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("usa.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Plot horizontal bar chart
plt.figure(figsize=(10,12))
sns.barplot(data=wiki_genre_freq, y="Genre", x="Frequency", palette="mako")

# Labels and title
plt.title("Frequency of Genres (first word only)", fontsize=14)
plt.xlabel("Frequency")
plt.ylabel("Genre")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("global.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Plot as pie chart
plt.figure(figsize=(8,8))
plt.pie(wiki_genre_freq["Frequency"], labels=wiki_genre_freq["Genre"], autopct='%1.1f%%', startangle=140)
plt.title("Genre Distribution (first word only)")
plt.show()

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("global.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Add relative frequency (percentage)
total = wiki_genre_freq["Frequency"].sum()
wiki_genre_freq["Relative Frequency"] = (wiki_genre_freq["Frequency"] / total * 100).round(2)

# Print table
print(wiki_genre_freq)
# Out:
#            Genre  Frequency  Relative Frequency
# 0            pop         18               15.65
# 1            r&b         11                9.57
# 2      synth-pop          9                7.83
# 3            new          5                4.35
# 4    alternative          5                4.35
# 5          indie          5                4.35
# 6        country          5                4.35
# 7        electro          4                3.48
# 8            hip          3                2.61
# 9      reggaeton          3                2.61
# 10          funk          3                2.61
# 11     dance-pop          2                1.74
# 12         dance          2                1.74
# 13     downtempo          2                1.74
# 14          folk          2                1.74
# 15     blue-eyed          1                0.87
# 16       baroque          1                0.87
# 17          soul          1                0.87
# 18      nu-disco          1                0.87
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("usa.csv")

# Split "Wiki Genre" into individual genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")

# Flatten and take only the first word of each genre
all_genres = [genre.split()[0] for sublist in wiki_genres for genre in sublist]

# Normalize to lowercase
all_genres = [g.lower() for g in all_genres]

# Create frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Add relative frequency (percentage)
total = wiki_genre_freq["Frequency"].sum()
wiki_genre_freq["Relative Frequency"] = (wiki_genre_freq["Frequency"] / total * 100).round(2)

# Print table
print(wiki_genre_freq)
# Out:
#            Genre  Frequency  Relative Frequency
# 0            pop         18               15.79
# 1        country         12               10.53
# 2            r&b          8                7.02
# 3      synth-pop          7                6.14
# 4    alternative          5                4.39
# 5          dance          4                3.51
# 6            new          4                3.51
# 7        electro          4                3.51
# 8      dance-pop          4                3.51
# 9           folk          3                2.63
# 10           hip          3                2.63
# 11          trap          3                2.63
# 12          funk          2                1.75
# 13         indie          2                1.75
# 14     downtempo          2                1.75
# 15          soft          2                1.75
# 16     blue-eyed          1                0.88
# 17     disco-pop          1                0.88
# 18         hyphy          1                0.88
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("global.csv")

# Split and clean genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")
all_genres = [genre.split()[0].lower() for sublist in wiki_genres for genre in sublist]

# Frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Limit to top 10, group rest into "Other"
top10 = wiki_genre_freq.head(10)
other_sum = wiki_genre_freq["Frequency"].iloc[10:].sum()
top10.loc[len(top10)] = ["Other", other_sum]

# Pie chart
plt.figure(figsize=(8,8))
plt.pie(
    top10["Frequency"],
    labels=top10["Genre"],
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.8,   # move % closer to center
    labeldistance=1.1  # push labels outward
)
plt.title("Top 10 Genres (first word only)", fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_136/3524266404.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10.loc[len(top10)] = ["Other", other_sum]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load dataset
df = pd.read_csv("global.csv")

# Split and clean genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")
all_genres = [genre.split()[0].lower() for sublist in wiki_genres for genre in sublist]

# Frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Limit to top 10, group rest into "Other"
top10 = wiki_genre_freq.head(10)
other_sum = wiki_genre_freq["Frequency"].iloc[10:].sum()
top10.loc[len(top10)] = ["Other", other_sum]

# Generate unique colors using a colormap
colors = cm.tab20.colors[:len(top10)]  # pick N distinct colors

# Pie chart
plt.figure(figsize=(8,8))
plt.pie(
    top10["Frequency"],
    labels=top10["Genre"],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,        # apply unique colors
    pctdistance=0.8,      # move % closer to center
    labeldistance=1.1     # push labels outward
)
plt.title("Top 10 Genres (first word only)", fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_136/1892032102.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10.loc[len(top10)] = ["Other", other_sum]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load dataset
df = pd.read_csv("usa.csv")

# Split and clean genres
wiki_genres = df["Wiki Genre"].dropna().str.split(", ")
all_genres = [genre.split()[0].lower() for sublist in wiki_genres for genre in sublist]

# Frequency table
wiki_genre_freq = pd.Series(all_genres).value_counts().reset_index()
wiki_genre_freq.columns = ["Genre", "Frequency"]

# Limit to top 10, group rest into "Other"
top10 = wiki_genre_freq.head(10)
other_sum = wiki_genre_freq["Frequency"].iloc[10:].sum()
top10.loc[len(top10)] = ["Other", other_sum]

# Generate unique colors using a colormap
colors = cm.tab20.colors[:len(top10)]  # pick N distinct colors

# Pie chart
plt.figure(figsize=(8,8))
plt.pie(
    top10["Frequency"],
    labels=top10["Genre"],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,        # apply unique colors
    pctdistance=0.8,      # move % closer to center
    labeldistance=1.1     # push labels outward
)
plt.title("Top 10 Genres (first word only)", fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_136/3282982973.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10.loc[len(top10)] = ["Other", other_sum]

# %% [markdown]
# Many genres wasn't very popular for the global tracks like soul, nu-disco, power, europop, dark, soft, industrial, pop-soul, yacht, disco-pop, hyphy, west, electro-funk, lounge, gothic, rage, uk, merengue, regional, urban, ranchera, funk-pop, pop-rap, post-britpop, art, disco, hip-hop, trap, synth-rock, post-punk, folk-pop, twee, synthwave, amapiano, while in US tracks blue-eyed, disco-pop, hyphy, west, nu-disco, electro-funk, yacht, baroque, hick, hip-hop, hardcore, gothic, industrial, pop-rap, soul, lounge, rage, power, europop, dark, pop-soul, neo, disco, bubble, synth-disco, synth-pop., pop-punk, christian, glam-pop, slacker, rock. In other words, there is some difference between the less popular ones between global and the US, but there are also some that were at the bottom of the list, like soul, that appear in US and global. These songs were at the bottom, but they share the same percentage. For example, in the US, they represent 0.88% and globally 0.87% but since there are many, they represent more than the most popular. There is some bias, like the use of a wiki, which makes it harder to know if it is true, since any person can change anything and make this table wrong, so take this as one answer to the question, but you need to double-check so you don't get it wrong.
