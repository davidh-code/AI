# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %%
import pandas as pd
df = pd.read_excel('table.xlsx')

# %%
df.tail()
# Out:
#    Country of Origin  Total Passenger Count by Country  \
# 39            Turkey                                 6
# 40    United Kingdom                               355
# 41     United States                               300
# 42           Unknown                                 2
# 43           Uruguay                                 2
#
#     Percentage of Passengers by Country  \
# 39                               0.0045
# 40                               0.2685
# 41                               0.2269
# 42                               0.0015
# 43                               0.0015
#
#     First Class Passenger Count by Country  \
# 39                                       0
# 40                                      44
# 41                                     210
# 42                                       0
# 43                                       0
#
#     Percentage of First Class Passengers by Country  \
# 39                                           0.0000
# ...
