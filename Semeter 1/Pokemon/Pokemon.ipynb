# %% [markdown]
# # How does the damage power of Charmander compare with the other Pokémon of the first generation without evolution?
# This will need a part of pokemons population of the fist generation, and is observational since we can't change the amount of damage a pokemon do. I will search for all the pokemons info without evolution so that they be equal and see where is located charmander in terms of power. I collected the information from Research AI which used Wikipedia and use a public database of pokemon fan made since it was used this people could change how really the stats from pokemons were in its origin but also since I used AI it could skip some important infomation and simply it, either way I did some checks with the fan made city and it look similar. There is another bias which is that i copy and paste from a part making that in case i miss something to copy the information can be wrong.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Pokémon dataset (make sure the file is in the same folder as your notebook)
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Plot histogram
plt.figure(figsize=(10,6))
plt.hist(attack_values, bins=15, edgecolor="black")
plt.title("Attack Damage Distribution of Base Form Pokémon (Gen 1)")
plt.xlabel("Attack")
plt.ylabel("Frequency")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
import pandas as pd

# Load the Pokémon dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Select only the numerical columns
numeric_cols = ["HP", "Attack", "Defense", "Special", "Speed", "Total"]

# Compute the five number summary for each numeric stat
summary = base_pokemon[numeric_cols].describe(percentiles=[0.25, 0.5, 0.75]).loc[["min","25%","50%","75%","max"]]

print("Five Number Summary (Base Form Pokémon Only):")
print(summary)
# Out:
# Five Number Summary (Base Form Pokémon Only):
#         HP  Attack  Defense  Special  Speed  Total
# min   10.0     5.0      5.0     20.0   15.0  175.0
# 25%   40.0    45.0     41.5     40.0   41.5  251.5
# 50%   50.0    56.0     55.0     50.0   60.0  275.0
# 75%   65.0    81.5     80.0     72.5   86.0  342.5
# max  250.0   125.0    160.0    154.0  130.0  590.0

# %%
import pandas as pd

# Load the Pokémon dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Calculate measures of central tendency
mean_attack = attack_values.mean()
median_attack = attack_values.median()
mode_attack = attack_values.mode().tolist()  # could be more than one mode

print("Measures of Central Tendency for Attack (Base Form Pokémon Only):")
print(f"Mean:   {mean_attack:.2f}")
print(f"Median: {median_attack}")
print(f"Mode:   {mode_attack}")
# Out:
# Measures of Central Tendency for Attack (Base Form Pokémon Only):
# Mean:   63.70
# Median: 56.0
# Mode:   [45]

# %%
import pandas as pd

# Load the Pokémon dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Calculate measures of spread
attack_range = attack_values.max() - attack_values.min()
attack_variance = attack_values.var()
attack_std = attack_values.std()
attack_iqr = attack_values.quantile(0.75) - attack_values.quantile(0.25)

print("Measures of Spread for Attack (Base Form Pokémon Only):")
print(f"Range: {attack_range}")
print(f"Variance: {attack_variance:.2f}")
print(f"Standard Deviation: {attack_std:.2f}")
print(f"IQR (Interquartile Range): {attack_iqr}")
# Out:
# Measures of Spread for Attack (Base Form Pokémon Only):
# Range: 120
# Variance: 655.78
# Standard Deviation: 25.61
# IQR (Interquartile Range): 36.5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Pokémon dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Create box plot
plt.figure(figsize=(6, 8))
plt.boxplot(attack_values, vert=True, patch_artist=True, boxprops=dict(facecolor="lightblue"))
plt.title("Box Plot of Attack (Base Form Pokémon Only)")
plt.ylabel("Attack Value")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Sort base Pokémon by Attack (descending = strongest first)
sorted_attack = base_pokemon.sort_values(by="Attack", ascending=False).reset_index(drop=True)

# Find Charmander's position
charmander_position = sorted_attack[sorted_attack["Name"] == "Charmander"].index[0] + 1  # +1 to make it human-readable rank

# Total number of base form Pokémon
total_base = len(sorted_attack)

print(f"Charmander's Attack rank: {charmander_position} out of {total_base} base form Pokémon")
# Out:
# Charmander's Attack rank: 47 out of 79 base form Pokémon

# %% [markdown]
# Charmander's attack is below the average of base Pokémon (47 out of 79 base form Pokémon) in attack damage, not special damage; it is somewhat stronger than the weakest Pokémon. In the box plot, he would be on the lowest side, not fully at the bottom, but it will be closer there. This answer was taken from a fan-made website about all the Pokémon stats, but it is not an official one, so my answer that he is lower than average could be incorrect. Therefore, please don't take it as the definitive answer. AI wrote the code, so in case I skip some details answer the answer could be even wrong.

# %%
import pandas as pd
from scipy.stats import zscore

# Load the dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Calculate z-scores for all base Pokémon
attack_zscores = zscore(attack_values)

# Add z-scores to the dataframe
base_pokemon = base_pokemon.copy()
base_pokemon["Attack_Z"] = attack_zscores

# Get Charmander's z-score
charmander_z = base_pokemon[base_pokemon["Name"] == "Charmander"]["Attack_Z"].values[0]

print(f"Charmander's Attack z-score: {charmander_z:.2f}")
# Out:
# Charmander's Attack z-score: -0.46

# %%
import pandas as pd
from scipy.stats import percentileofscore

# Load the dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon (those without "Evolves From")
base_pokemon = df[df["Evolves From"].isna()]

# Extract Attack values
attack_values = base_pokemon["Attack"]

# Get Charmander's attack
charmander_attack = df[df["Name"] == "Charmander"]["Attack"].values[0]

# Calculate percentile rank of Charmander's attack
charmander_percentile = percentileofscore(attack_values, charmander_attack, kind="rank")

print(f"Charmander's Attack: {charmander_attack}")
print(f"Charmander is at the {charmander_percentile:.2f}th percentile among base form Pokémon")
# Out:
# Charmander's Attack: 52
# Charmander is at the 41.14th percentile among base form Pokémon

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Pokemon.csv")

# Keep only base form Pokémon
base_pokemon = df[df["Evolves From"].isna()]

# Extract attack values
attack_values = base_pokemon["Attack"]

# Get Charmander's attack
charmander_attack = df[df["Name"] == "Charmander"]["Attack"].values[0]

# Measures of spread
attack_range = attack_values.max() - attack_values.min()
attack_variance = attack_values.var()
attack_std = attack_values.std()
attack_iqr = attack_values.quantile(0.75) - attack_values.quantile(0.25)

print("Measures of Spread (Attack - Base Form Pokémon):")
print(f"Range: {attack_range}")
print(f"Variance: {attack_variance:.2f}")
print(f"Standard Deviation: {attack_std:.2f}")
print(f"IQR: {attack_iqr}\n")

print(f"Charmander's Attack = {charmander_attack}")
# Out:
# Measures of Spread (Attack - Base Form Pokémon):
# Range: 120
# Variance: 655.78
# Standard Deviation: 25.61
# IQR: 36.5
#
# Charmander's Attack = 52

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("Pokemon.csv")

# Attack values
all_attack = df["Attack"]
base_attack = df[df["Evolves From"].isna()]["Attack"]

# Charmander's Attack
charmander_attack = df[df["Name"] == "Charmander"]["Attack"].values[0]

# Plot density curves
plt.figure(figsize=(12,6))
sns.kdeplot(all_attack, fill=True, alpha=0.5, color="blue", label="All Pokémon")
sns.kdeplot(base_attack, fill=True, alpha=0.5, color="green", label="Base Form Pokémon")

# Add vertical line for Charmander
plt.axvline(charmander_attack, color="red", linestyle="--", linewidth=2)
plt.text(charmander_attack+1, 0.01, f"Charmander Attack = {charmander_attack}", 
         rotation=90, color="red", fontsize=10, verticalalignment="bottom")

# Labels
plt.title("Attack Distribution: All Pokémon vs Base Form Pokémon")
plt.xlabel("Attack Value")
plt.ylabel("Density")
plt.legend()
plt.grid(alpha=0.3)

plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import gaussian_kde, percentileofscore

# Load dataset
df = pd.read_csv("Pokemon.csv")

# Base form Pokémon attack values
base_attack = df[df["Evolves From"].isna()]["Attack"]

# Charmander's Attack
charmander_attack = df[df["Name"] == "Charmander"]["Attack"].values[0]

# Density estimation
kde = gaussian_kde(base_attack)
x = np.linspace(base_attack.min(), base_attack.max(), 500)
y = kde(x)

# Calculate Charmander's percentile
charmander_percentile = percentileofscore(base_attack, charmander_attack, kind="rank")

# Plot density curve
plt.figure(figsize=(12,6))
plt.plot(x, y, color="green", linewidth=2, label="Base Form Pokémon Attack Distribution")
plt.fill_between(x[x <= charmander_attack], y[x <= charmander_attack], color="green", alpha=0.4)

# Add Charmander's line
plt.axvline(charmander_attack, color="red", linestyle="--", linewidth=2)
plt.text(charmander_attack+1, max(y)*0.5, 
         f"Charmander Attack = {charmander_attack}\n({charmander_percentile:.1f}th percentile)",
         color="red", fontsize=10, rotation=90, va="center")

# Labels
plt.title("Charmander's Attack Percentile Among Base Form Pokémon")
plt.xlabel("Attack Value")
plt.ylabel("Density")
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# Charmander is below the middle of damage power by being in the 41.1th percentile, but also its z-score is -0.4,6 meaning that it is weaker than the average Pokémon attack power. Since it is above -1, it means that he is weak but not much. Charmander is close to the pith of the graph, meaning that its attack power is closer to the middle, where many Pokémon are. Since this information was obtained from a non-verified source, it may have wrong information since I used AI to make graphs, which could be wrong, and make words like damage confused with special, or even that it counts allPokémons that my question doesn't need.
